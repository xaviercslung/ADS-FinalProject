# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as dd
import pyspark
import csv
from datetime import datetime

# %%
# download dataset

# !wget https://data.cityofnewyork.us/api/views/tqtj-sjs8/rows.csv?accessType=DOWNLOAD
# !wget https://data.cityofnewyork.us/api/views/h9gi-nx95/rows.csv?accessType=DOWNLOAD&bom=true&query=select+*
# !wget https://data.cityofnewyork.us/api/views/tqtj-sjs8/rows.csv?accessType=DOWNLOAD

# %%
# motor_df = pd.read_csv('./data/Motor_Vehicle_Collisions_-_Person.csv')

# %%
# motor_df.head()

# %%
# motor_df['PED_LOCATION'].unique()

# %%
# missingValue = motor_df.isna().sum().to_frame(name='NaN_number')
# missingValue.sort_values('NaN_number',inplace=True,ascending=False)
# missingValue.plot.bar(color='blue',figsize=(15,7))
# plt.title('Missing Value of Motor Vehicle Collisions dataset',fontsize=15)
# plt.legend()
# plt.show()

# %%
crash_df = pd.read_csv('./data/Motor_Vehicle_Collisions_-_Crashes.csv',dtype={'BOROUGH':str,'ZIP CODE':str})

# %%
# crash_df.columns.unique().to_list()

# %%
crash_df['CRASH DATE'] = pd.to_datetime(crash_df['CRASH DATE'])
crash_df['CRASH DATE'].sort_values(ascending=False)
crash_df['dow'] = pd.to_datetime(crash_df['CRASH DATE']).dt.dayofweek
crash_df['day'] = pd.to_datetime(crash_df['CRASH DATE']).dt.day
crash_df['year'] = pd.to_datetime(crash_df['CRASH DATE']).dt.year

# %%
crash_df['Killed'] = crash_df['NUMBER OF PERSONS KILLED']+\
                        crash_df['NUMBER OF PEDESTRIANS KILLED']+crash_df['NUMBER OF CYCLIST KILLED']
crash_df['Injured'] = crash_df['NUMBER OF PERSONS INJURED']+\
                        crash_df['NUMBER OF PEDESTRIANS INJURED']+crash_df['NUMBER OF CYCLIST INJURED']

# %%
crash_df.head()
# Out:
#   CRASH DATE CRASH TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0 2020-03-13      11:00            NaN      NaN  40.655518  -74.00644
# 1 2020-05-19      12:04            NaN      NaN  40.603070  -74.01667
# 2 2020-04-09      23:45       BROOKLYN    11207  40.675526  -73.90132
# 3 2020-05-26       0:53  STATEN ISLAND    10306  40.574898  -74.09110
# 4 2020-03-14      15:30       BROOKLYN    11234  40.625633  -73.90917
#
#                  LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0  (40.655518, -74.00644)  3 AVENUE                                       NaN
# 1   (40.60307, -74.01667)  BELT PARKWAY                                   NaN
# 2  (40.675526, -73.90132)                               NaN               NaN
# 3   (40.574898, -74.0911)  OLYMPIA BOULEVARD                    HUNTER AVENUE
# 4  (40.625633, -73.90917)  BERGEN AVENUE                          ROYCE PLACE
#
#                             OFF STREET NAME  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2  2517      ATLANTIC AVENUE                 ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0  Station Wagon/Sport Utility Vehicle                 Tractor Truck Diesel
# 1  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 2                                Sedan                                Sedan
# 3  Station Wagon/Sport Utility Vehicle                        Pick-up Truck
# 4                        Pick-up Truck                                  NaN
#
#    VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4  VEHICLE TYPE CODE 5  dow  day  \
# 0                  NaN                  NaN                  NaN    4   13
# 1                Sedan                  NaN                  NaN    1   19
# 2                  NaN                  NaN                  NaN    3    9
# 3                  NaN                  NaN                  NaN    1   26
# 4                  NaN                  NaN                  NaN    5   14
#
#    year Killed Injured
# 0  2020    0.0     0.0
# 1  2020    0.0     3.0
# 2  2020    0.0     2.0
# 3  2020    0.0     0.0
# 4  2020    0.0     0.0
#
# [5 rows x 34 columns]

# %%
crash_df.isna().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           541636
# ZIP CODE                          541847
# LATITUDE                          208858
# LONGITUDE                         208858
# LOCATION                          208858
# ON STREET NAME                    355423
# CROSS STREET NAME                 620171
# OFF STREET NAME                  1500153
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       4960
# CONTRIBUTING FACTOR VEHICLE 2     249675
# CONTRIBUTING FACTOR VEHICLE 3    1645038
# CONTRIBUTING FACTOR VEHICLE 4    1737783
# CONTRIBUTING FACTOR VEHICLE 5    1756567
# COLLISION_ID                           0
# VEHICLE TYPE CODE 1                 9289
# VEHICLE TYPE CODE 2               291858
# VEHICLE TYPE CODE 3              1648248
# VEHICLE TYPE CODE 4              1738496
# VEHICLE TYPE CODE 5              1756741
# dow                                    0
# day                                    0
# year                                   0
# Killed                                31
# Injured                               18
# dtype: int64

# %%
# TODO: Use latitude and longitude to get the borough name
crash = crash_df[crash_df['LATITUDE'].notna()].copy()
crash.isna().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           364392
# ZIP CODE                          364586
# LATITUDE                               0
# LONGITUDE                              0
# LOCATION                               0
# ON STREET NAME                    302160
# CROSS STREET NAME                 541378
# OFF STREET NAME                  1314233
# NUMBER OF PERSONS INJURED             16
# NUMBER OF PERSONS KILLED              28
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       4455
# CONTRIBUTING FACTOR VEHICLE 2     224480
# CONTRIBUTING FACTOR VEHICLE 3    1450701
# CONTRIBUTING FACTOR VEHICLE 4    1531858
# CONTRIBUTING FACTOR VEHICLE 5    1548388
# COLLISION_ID                           0
# VEHICLE TYPE CODE 1                 8329
# VEHICLE TYPE CODE 2               264514
# VEHICLE TYPE CODE 3              1453573
# VEHICLE TYPE CODE 4              1532494
# VEHICLE TYPE CODE 5              1548537
# dow                                    0
# day                                    0
# year                                   0
# Killed                                28
# Injured                               16
# dtype: int64

# %%
# crash_year = crash_df[['year','COLLISION_ID','Killed','Injured']]\
#                 .groupby('year').agg({'COLLISION_ID':'count','Killed':'sum','Injured':'sum'})\
#                 .reset_index()\
#                 .rename(columns={'COLLISION_ID':'Number of Collsion'})
# crash_year = crash_year[crash_year['year']!=2021]

# %%
# plt.figure(figsize=(10,5))
# plt.bar(crash_year.year,crash_year['Number of Collsion'],color='lightblue')
# plt.title('Number of Collisions from 2012 to 2020',fontsize=20,color='white')
# plt.ylabel('Collisions',fontsize=15,color='white')
# plt.xticks(crash_year.year,fontsize=13,color='white')
# plt.yticks(fontsize=13,color='white')
# plt.grid(linestyle='--',axis='y')
# plt.savefig('collisions',dpi=300)
# plt.show()

# %%
# plt.figure(figsize=(10,5))
# plt.bar(crash_year.year,crash_year.Injured,color='lightblue')
# plt.title('Number of Injuries from 2012 to 2020',fontsize=20,color='white')
# plt.ylabel('Injuries',fontsize=15,color='white')
# plt.xticks(crash_year.year,fontsize=13,color='white')
# plt.yticks(fontsize=13,color='white')
# plt.grid(linestyle='--',axis='y')
# plt.savefig('injuries',dpi=300)
# plt.show()

# %%
# plt.figure(figsize=(10,5))
# plt.bar(crash_year.year,crash_year.Killed,color='lightblue')
# plt.title('Number of Fatalities from 2012 to 2020',fontsize=20,color='white')
# plt.ylabel('Fatalities',fontsize=15,color='white')
# plt.xticks(crash_year.year,fontsize=13,color='white')
# plt.yticks(fontsize=13,color='white')
# plt.grid(linestyle='--',axis='y')
# plt.savefig('fatalities',dpi=300)
# plt.show()

# %%
# missing_value_crash = crash_df.isna().sum().to_frame(name='NaN_number')
# missing_value_crash.sort_values('NaN_number',inplace=True,ascending=False)
# missing_value_crash.plot.bar(color='blue',figsize=(15,7))
# plt.title('Missing Value of Motor Vehicle Collisions dataset',fontsize=15)
# plt.legend()
# plt.show()

# %%
permit_df = pd.read_csv('./data/Street_Construction_Permits.csv',low_memory=False)

# %%
permit_df.isna().sum()
# Out:
# PermitNumber                          0
# ApplicationTrackingID           6150227
# SequenceNumber                  5579305
# ApplicationTypeShortDesc        6150227
# PermitStatusID                      229
# PermitStatusShortDesc               229
# PermitSeriesID                        0
# PermitSeriesShortDesc                 0
# PermitTypeID                          0
# PermitTypeDesc                        0
# PermitNumberOfZones             3722517
# PermitLinearFeet                5425553
# PermitTotalSqFeet               8193368
# PermitEstimatedNumberOfCuts     6834771
# EquipmentTypeDesc               9798652
# NumberOfContainers             10292775
# NumberOfMiniContainers         10339616
# SpecificStipulations            4461181
# PreviousPermitNumber            7199019
# NextPermitNumber                7600226
# EmergencyIssueDate              9894586
# PermitIssueDate                   21802
# IssuedWorkStartDate               46342
# IssuedWorkEndDate                 59682
# BoroughName                      290964
# PermitHouseNumber               5889327
# OnStreetName                     306373
# FromStreetName                   306679
# ToStreetName                    1917186
# PermitteeName                         0
# PermitPurposeComments           5175693
# PermitLocationComments          5890732
# PavementShortDesc               4102946
# SideWalkShortDesc               4273091
# CreatedOn                             0
# ModifiedOn                            0
# dtype: int64

# %%
permit_df.head()
# Out:
#     PermitNumber  ApplicationTrackingID  SequenceNumber  \
# 0  Q012007305130                    NaN             NaN
# 1  X042012258017                    NaN             NaN
# 2  X012010223030                    NaN             NaN
# 3  X012006219032                    NaN             NaN
# 4  X011999076002                    NaN             NaN
#
#   ApplicationTypeShortDesc PermitStatusID          PermitStatusShortDesc  \
# 0                      NaN             15  DELINQUENT CUTFORM/COMPACTION
# 1                      NaN             30                        EXPIRED
# 2                      NaN             30                        EXPIRED
# 3                      NaN             30                        EXPIRED
# 4                      NaN             15  DELINQUENT CUTFORM/COMPACTION
#
#    PermitSeriesID         PermitSeriesShortDesc PermitTypeID  \
# 0               1         STREET OPENING PERMIT         0162
# 1               4  SIDEWALK CONSTRUCTION PERMIT         0401
# 2               1         STREET OPENING PERMIT         0122
# 3               1         STREET OPENING PERMIT         0162
# 4               1         STREET OPENING PERMIT         0113
#
#                         PermitTypeDesc  ...          OnStreetName  \
# 0  NYC PARKS - RECONSTRUCTION CONTRACT  ...  CLOVERDALE BOULEVARD
# 1                      REPAIR SIDEWALK  ...        HOLLAND AVENUE
# 2                           REPAIR GAS  ...         MICKLE AVENUE
# 3  NYC PARKS - RECONSTRUCTION CONTRACT  ...       BRONX BOULEVARD
# 4                         REPAIR WATER  ...      EAST  165 STREET
#
#     FromStreetName     ToStreetName                 PermitteeName  \
# 0          57 ROAD        59 AVENUE        FERRANDINO & SON, INC.
# 1  ALLERTON AVENUE     ARNOW AVENUE        KIANI CONTRACTING INC.
# 2      ADEE AVENUE     ARNOW AVENUE           CONSOLIDATED EDISON
# 3   MAGENTA STREET  ROSEWOOD STREET  LAKHI GENERAL CONTRACTOR INC
# 4    GERARD AVENUE    WALTON AVENUE    N.Y.C.WATER MAIN WORKS INC
#
#                PermitPurposeComments  \
# 0                           MOSY1841
# 1                                NaN
# 2  001009673701201008120001000396737
# 3                           MOS77841
# 4                                NaN
#
#                               PermitLocationComments  PavementShortDesc  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  SUBMITTED AS:MICKLE AVENUE ARNOW AVENUE ADEE A...            ASPHALT
# 3                                                NaN            ASPHALT
# 4                                                NaN            ASPHALT
#
#   SideWalkShortDesc                     CreatedOn  \
# 0          CONCRETE  12/14/2013 09:03:08 PM +0000
# 1          CONCRETE  12/14/2013 09:03:08 PM +0000
# 2          CONCRETE  12/14/2013 09:03:08 PM +0000
# 3          CONCRETE  12/14/2013 09:03:08 PM +0000
# 4               NaN  12/14/2013 09:03:08 PM +0000
#
#                      ModifiedOn
# 0  12/14/2013 09:03:08 PM +0000
# 1  06/22/2018 08:16:47 PM +0000
# 2  12/14/2013 09:03:08 PM +0000
# 3  12/14/2013 09:03:08 PM +0000
# 4  12/14/2013 09:03:08 PM +0000
#
# [5 rows x 36 columns]

# %%
permit = permit_df[(permit_df['BoroughName'].notna()) & (permit_df['OnStreetName'].notna())\
                & (permit_df['IssuedWorkStartDate'].notna()) & (permit_df['IssuedWorkEndDate'].notna())].copy()

# %%
permit.shape
# Out:
# (10096248, 36)

# %%
permit = permit[['PermitNumber','BoroughName','OnStreetName','IssuedWorkStartDate','IssuedWorkEndDate']].reset_index(drop=True)

# %%
permit.head()
# Out:
#     PermitNumber BoroughName          OnStreetName  \
# 0  Q012007305130      QUEENS  CLOVERDALE BOULEVARD
# 1  X042012258017       BRONX        HOLLAND AVENUE
# 2  X012010223030       BRONX         MICKLE AVENUE
# 3  X012006219032       BRONX       BRONX BOULEVARD
# 4  X011999076002       BRONX      EAST  165 STREET
#
#             IssuedWorkStartDate             IssuedWorkEndDate
# 0  11/01/2007 12:00:00 AM +0000  12/31/2007 12:00:00 AM +0000
# 1  09/17/2012 12:00:00 AM +0000  10/17/2012 12:00:00 AM +0000
# 2  08/17/2010 12:00:00 AM +0000  09/16/2010 12:00:00 AM +0000
# 3  08/07/2006 12:00:00 AM +0000  09/30/2006 12:00:00 AM +0000
# 4  03/17/1999 12:00:00 AM +0000  03/31/1999 12:00:00 AM +0000

# %%
permit.to_csv('permit.csv')

# %%
permit_dd = dd.read_csv('./data/Street_Construction_Permits.csv',dtype=str)

# %%
permit_dd['IssuedWorkStartDate'] = dd.to_datetime(permit_dd['IssuedWorkStartDate'],errors = 'coerce')
permit_dd['IssuedWorkEndDate'] = dd.to_datetime(permit_dd['IssuedWorkEndDate'],errors = 'coerce')

# %%
permit_dd = permit_dd.dropna(subset=['BoroughName','OnStreetName','IssuedWorkStartDate','IssuedWorkEndDate'])
permit_dd = permit_dd[['BoroughName','OnStreetName','IssuedWorkStartDate','IssuedWorkEndDate']]

# %%
permit_dd['year'] = permit_dd['IssuedWorkStartDate'].dt.year

# %%
permit_dd= permit_dd[(permit_dd['year']>=2016) & (permit_dd['year']<2020)]

# %%
permit_dd['IssuedWorkStartDate'] = permit_dd['IssuedWorkStartDate'].dt.date
permit_dd['IssuedWorkEndDate'] = permit_dd['IssuedWorkEndDate'].dt.date

# %%
permit_dd.head()
# Out:
# /home/valx/anaconda3/lib/python3.8/site-packages/dask/dataframe/core.py:6194: UserWarning: Insufficient elements for `head`. 5 elements requested, only 0 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# Empty DataFrame
# Columns: [BoroughName, OnStreetName, IssuedWorkStartDate, IssuedWorkEndDate, year]
# Index: []

# %%
import pyspark
sc = pyspark.SparkContext()
sc
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>

# %%
# for result in perdelta(date(2011, 10, 10), date(2011, 12, 12), timedelta(days=1)):

# %%
from datetime import date, datetime, timedelta

def data_time_range(record):
    import datetime
    split_sdate = record[4].split(' ')[0].split('/')
    start = (split_sdate[2],split_sdate[0],split_sdate[1])
    start = datetime.datetime(*map(int, start ))
    
    split_edate = record[5].split(' ')[0].split('/')
    end = (split_edate[2],split_edate[0],split_edate[1])
    end = datetime.datetime(*map(int, end ))
    return (record[2],record[3],start,end)
def year_filter(record):
    import datetime
    sd = datetime.datetime(2016,1,1)
    ed = datetime.datetime(2019,12,31)
    if record[2] > sd and record[3] < ed:
        return True
    else:
        return False
def range_of_date(record):
    from datetime import date, datetime, timedelta
    l = []
    for result in perdelta(record[2], record[3], timedelta(days=1)):
        l.append((result,1))
    res_tuple = [(record[0],record[1])]
    for i in l:
        res_tuple.append(i)
    return ((record[0],record[1]),res_tuple)

def perdelta(start, end, delta):
    curr = start
    while curr <= end:
        yield curr
        curr += delta
sc.textFile('permit.csv')\
    .map(lambda x: next(csv.reader([x])))\
    .filter(lambda x: x[1] != 'PermitNumber')\
    .map(data_time_range)\
    .filter(year_filter)\
    .map(range_of_date)\
    .reduceByKey(lambda x,y: x+y).take(5)
# Out:
# [(('BROOKLYN', 'QUENTIN ROAD'),
#   [('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2018, 2, 13, 0, 0), 1),
#    (datetime.datetime(2018, 2, 14, 0, 0), 1),
#    (datetime.datetime(2018, 2, 15, 0, 0), 1),
#    (datetime.datetime(2018, 2, 16, 0, 0), 1),
#    (datetime.datetime(2018, 2, 17, 0, 0), 1),
#    (datetime.datetime(2018, 2, 18, 0, 0), 1),
#    (datetime.datetime(2018, 2, 19, 0, 0), 1),
#    (datetime.datetime(2018, 2, 20, 0, 0), 1),
#    (datetime.datetime(2018, 2, 21, 0, 0), 1),
#    (datetime.datetime(2018, 2, 22, 0, 0), 1),
#    (datetime.datetime(2018, 2, 23, 0, 0), 1),
#    (datetime.datetime(2018, 2, 24, 0, 0), 1),
#    (datetime.datetime(2018, 2, 25, 0, 0), 1),
#    (datetime.datetime(2018, 2, 26, 0, 0), 1),
#    (datetime.datetime(2018, 2, 27, 0, 0), 1),
#    (datetime.datetime(2018, 2, 28, 0, 0), 1),
#    (datetime.datetime(2018, 3, 1, 0, 0), 1),
#    (datetime.datetime(2018, 3, 2, 0, 0), 1),
#    (datetime.datetime(2018, 3, 3, 0, 0), 1),
#    (datetime.datetime(2018, 3, 4, 0, 0), 1),
#    (datetime.datetime(2018, 3, 5, 0, 0), 1),
#    (datetime.datetime(2018, 3, 6, 0, 0), 1),
#    (datetime.datetime(2018, 3, 7, 0, 0), 1),
#    (datetime.datetime(2018, 3, 8, 0, 0), 1),
#    (datetime.datetime(2018, 3, 9, 0, 0), 1),
#    (datetime.datetime(2018, 3, 10, 0, 0), 1),
#    (datetime.datetime(2018, 3, 11, 0, 0), 1),
#    (datetime.datetime(2018, 3, 12, 0, 0), 1),
#    (datetime.datetime(2018, 3, 13, 0, 0), 1),
#    (datetime.datetime(2018, 3, 14, 0, 0), 1),
#    (datetime.datetime(2018, 3, 15, 0, 0), 1),
#    (datetime.datetime(2018, 3, 16, 0, 0), 1),
#    (datetime.datetime(2018, 3, 17, 0, 0), 1),
#    (datetime.datetime(2018, 3, 18, 0, 0), 1),
#    (datetime.datetime(2018, 3, 19, 0, 0), 1),
#    (datetime.datetime(2018, 3, 20, 0, 0), 1),
#    (datetime.datetime(2018, 3, 21, 0, 0), 1),
#    (datetime.datetime(2018, 3, 22, 0, 0), 1),
#    (datetime.datetime(2018, 3, 23, 0, 0), 1),
#    (datetime.datetime(2018, 3, 24, 0, 0), 1),
#    (datetime.datetime(2018, 3, 25, 0, 0), 1),
#    (datetime.datetime(2018, 3, 26, 0, 0), 1),
#    (datetime.datetime(2018, 3, 27, 0, 0), 1),
#    (datetime.datetime(2018, 3, 28, 0, 0), 1),
#    (datetime.datetime(2018, 3, 29, 0, 0), 1),
#    (datetime.datetime(2018, 3, 30, 0, 0), 1),
#    (datetime.datetime(2018, 3, 31, 0, 0), 1),
#    (datetime.datetime(2018, 4, 1, 0, 0), 1),
#    (datetime.datetime(2018, 4, 2, 0, 0), 1),
#    (datetime.datetime(2018, 4, 3, 0, 0), 1),
#    (datetime.datetime(2018, 4, 4, 0, 0), 1),
#    (datetime.datetime(2018, 4, 5, 0, 0), 1),
#    (datetime.datetime(2018, 4, 6, 0, 0), 1),
#    (datetime.datetime(2018, 4, 7, 0, 0), 1),
#    (datetime.datetime(2018, 4, 8, 0, 0), 1),
#    (datetime.datetime(2018, 4, 9, 0, 0), 1),
#    (datetime.datetime(2018, 4, 10, 0, 0), 1),
#    (datetime.datetime(2018, 4, 11, 0, 0), 1),
#    (datetime.datetime(2018, 4, 12, 0, 0), 1),
#    (datetime.datetime(2018, 4, 13, 0, 0), 1),
#    (datetime.datetime(2018, 4, 14, 0, 0), 1),
#    (datetime.datetime(2018, 4, 15, 0, 0), 1),
#    (datetime.datetime(2018, 4, 16, 0, 0), 1),
#    (datetime.datetime(2018, 4, 17, 0, 0), 1),
#    (datetime.datetime(2018, 4, 18, 0, 0), 1),
#    (datetime.datetime(2018, 4, 19, 0, 0), 1),
#    (datetime.datetime(2018, 4, 20, 0, 0), 1),
#    (datetime.datetime(2018, 4, 21, 0, 0), 1),
#    (datetime.datetime(2018, 4, 22, 0, 0), 1),
#    (datetime.datetime(2018, 4, 23, 0, 0), 1),
#    (datetime.datetime(2018, 4, 24, 0, 0), 1),
#    (datetime.datetime(2018, 4, 25, 0, 0), 1),
#    (datetime.datetime(2018, 4, 26, 0, 0), 1),
#    (datetime.datetime(2018, 4, 27, 0, 0), 1),
#    (datetime.datetime(2018, 4, 28, 0, 0), 1),
#    (datetime.datetime(2018, 4, 29, 0, 0), 1),
#    (datetime.datetime(2018, 4, 30, 0, 0), 1),
#    (datetime.datetime(2018, 5, 1, 0, 0), 1),
#    (datetime.datetime(2018, 5, 2, 0, 0), 1),
#    (datetime.datetime(2018, 5, 3, 0, 0), 1),
#    (datetime.datetime(2018, 5, 4, 0, 0), 1),
#    (datetime.datetime(2018, 5, 5, 0, 0), 1),
#    (datetime.datetime(2018, 5, 6, 0, 0), 1),
#    (datetime.datetime(2018, 5, 7, 0, 0), 1),
#    (datetime.datetime(2018, 5, 8, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 10, 4, 0, 0), 1),
#    (datetime.datetime(2017, 10, 5, 0, 0), 1),
#    (datetime.datetime(2017, 10, 6, 0, 0), 1),
#    (datetime.datetime(2017, 10, 7, 0, 0), 1),
#    (datetime.datetime(2017, 10, 8, 0, 0), 1),
#    (datetime.datetime(2017, 10, 9, 0, 0), 1),
#    (datetime.datetime(2017, 10, 10, 0, 0), 1),
#    (datetime.datetime(2017, 10, 11, 0, 0), 1),
#    (datetime.datetime(2017, 10, 12, 0, 0), 1),
#    (datetime.datetime(2017, 10, 13, 0, 0), 1),
#    (datetime.datetime(2017, 10, 14, 0, 0), 1),
#    (datetime.datetime(2017, 10, 15, 0, 0), 1),
#    (datetime.datetime(2017, 10, 16, 0, 0), 1),
#    (datetime.datetime(2017, 10, 17, 0, 0), 1),
#    (datetime.datetime(2017, 10, 18, 0, 0), 1),
#    (datetime.datetime(2017, 10, 19, 0, 0), 1),
#    (datetime.datetime(2017, 10, 20, 0, 0), 1),
#    (datetime.datetime(2017, 10, 21, 0, 0), 1),
#    (datetime.datetime(2017, 10, 22, 0, 0), 1),
#    (datetime.datetime(2017, 10, 23, 0, 0), 1),
#    (datetime.datetime(2017, 10, 24, 0, 0), 1),
#    (datetime.datetime(2017, 10, 25, 0, 0), 1),
#    (datetime.datetime(2017, 10, 26, 0, 0), 1),
#    (datetime.datetime(2017, 10, 27, 0, 0), 1),
#    (datetime.datetime(2017, 10, 28, 0, 0), 1),
#    (datetime.datetime(2017, 10, 29, 0, 0), 1),
#    (datetime.datetime(2017, 10, 30, 0, 0), 1),
#    (datetime.datetime(2017, 10, 31, 0, 0), 1),
#    (datetime.datetime(2017, 11, 1, 0, 0), 1),
#    (datetime.datetime(2017, 11, 2, 0, 0), 1),
#    (datetime.datetime(2017, 11, 3, 0, 0), 1),
#    (datetime.datetime(2017, 11, 4, 0, 0), 1),
#    (datetime.datetime(2017, 11, 5, 0, 0), 1),
#    (datetime.datetime(2017, 11, 6, 0, 0), 1),
#    (datetime.datetime(2017, 11, 7, 0, 0), 1),
#    (datetime.datetime(2017, 11, 8, 0, 0), 1),
#    (datetime.datetime(2017, 11, 9, 0, 0), 1),
#    (datetime.datetime(2017, 11, 10, 0, 0), 1),
#    (datetime.datetime(2017, 11, 11, 0, 0), 1),
#    (datetime.datetime(2017, 11, 12, 0, 0), 1),
#    (datetime.datetime(2017, 11, 13, 0, 0), 1),
#    (datetime.datetime(2017, 11, 14, 0, 0), 1),
#    (datetime.datetime(2017, 11, 15, 0, 0), 1),
#    (datetime.datetime(2017, 11, 16, 0, 0), 1),
#    (datetime.datetime(2017, 11, 17, 0, 0), 1),
#    (datetime.datetime(2017, 11, 18, 0, 0), 1),
#    (datetime.datetime(2017, 11, 19, 0, 0), 1),
#    (datetime.datetime(2017, 11, 20, 0, 0), 1),
#    (datetime.datetime(2017, 11, 21, 0, 0), 1),
#    (datetime.datetime(2017, 11, 22, 0, 0), 1),
#    (datetime.datetime(2017, 11, 23, 0, 0), 1),
#    (datetime.datetime(2017, 11, 24, 0, 0), 1),
#    (datetime.datetime(2017, 11, 25, 0, 0), 1),
#    (datetime.datetime(2017, 11, 26, 0, 0), 1),
#    (datetime.datetime(2017, 11, 27, 0, 0), 1),
#    (datetime.datetime(2017, 11, 28, 0, 0), 1),
#    (datetime.datetime(2017, 11, 29, 0, 0), 1),
#    (datetime.datetime(2017, 11, 30, 0, 0), 1),
#    (datetime.datetime(2017, 12, 1, 0, 0), 1),
#    (datetime.datetime(2017, 12, 2, 0, 0), 1),
#    (datetime.datetime(2017, 12, 3, 0, 0), 1),
#    (datetime.datetime(2017, 12, 4, 0, 0), 1),
#    (datetime.datetime(2017, 12, 5, 0, 0), 1),
#    (datetime.datetime(2017, 12, 6, 0, 0), 1),
#    (datetime.datetime(2017, 12, 7, 0, 0), 1),
#    (datetime.datetime(2017, 12, 8, 0, 0), 1),
#    (datetime.datetime(2017, 12, 9, 0, 0), 1),
#    (datetime.datetime(2017, 12, 10, 0, 0), 1),
#    (datetime.datetime(2017, 12, 11, 0, 0), 1),
#    (datetime.datetime(2017, 12, 12, 0, 0), 1),
#    (datetime.datetime(2017, 12, 13, 0, 0), 1),
#    (datetime.datetime(2017, 12, 14, 0, 0), 1),
#    (datetime.datetime(2017, 12, 15, 0, 0), 1),
#    (datetime.datetime(2017, 12, 16, 0, 0), 1),
#    (datetime.datetime(2017, 12, 17, 0, 0), 1),
#    (datetime.datetime(2017, 12, 18, 0, 0), 1),
#    (datetime.datetime(2017, 12, 19, 0, 0), 1),
#    (datetime.datetime(2017, 12, 20, 0, 0), 1),
#    (datetime.datetime(2017, 12, 21, 0, 0), 1),
#    (datetime.datetime(2017, 12, 22, 0, 0), 1),
#    (datetime.datetime(2017, 12, 23, 0, 0), 1),
#    (datetime.datetime(2017, 12, 24, 0, 0), 1),
#    (datetime.datetime(2017, 12, 25, 0, 0), 1),
#    (datetime.datetime(2017, 12, 26, 0, 0), 1),
#    (datetime.datetime(2017, 12, 27, 0, 0), 1),
#    (datetime.datetime(2017, 12, 28, 0, 0), 1),
#    (datetime.datetime(2017, 12, 29, 0, 0), 1),
#    (datetime.datetime(2017, 12, 30, 0, 0), 1),
#    (datetime.datetime(2017, 12, 31, 0, 0), 1),
#    (datetime.datetime(2018, 1, 1, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 5, 12, 0, 0), 1),
#    (datetime.datetime(2016, 5, 13, 0, 0), 1),
#    (datetime.datetime(2016, 5, 14, 0, 0), 1),
#    (datetime.datetime(2016, 5, 15, 0, 0), 1),
#    (datetime.datetime(2016, 5, 16, 0, 0), 1),
#    (datetime.datetime(2016, 5, 17, 0, 0), 1),
#    (datetime.datetime(2016, 5, 18, 0, 0), 1),
#    (datetime.datetime(2016, 5, 19, 0, 0), 1),
#    (datetime.datetime(2016, 5, 20, 0, 0), 1),
#    (datetime.datetime(2016, 5, 21, 0, 0), 1),
#    (datetime.datetime(2016, 5, 22, 0, 0), 1),
#    (datetime.datetime(2016, 5, 23, 0, 0), 1),
#    (datetime.datetime(2016, 5, 24, 0, 0), 1),
#    (datetime.datetime(2016, 5, 25, 0, 0), 1),
#    (datetime.datetime(2016, 5, 26, 0, 0), 1),
#    (datetime.datetime(2016, 5, 27, 0, 0), 1),
#    (datetime.datetime(2016, 5, 28, 0, 0), 1),
#    (datetime.datetime(2016, 5, 29, 0, 0), 1),
#    (datetime.datetime(2016, 5, 30, 0, 0), 1),
#    (datetime.datetime(2016, 5, 31, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2018, 4, 16, 0, 0), 1),
#    (datetime.datetime(2018, 4, 17, 0, 0), 1),
#    (datetime.datetime(2018, 4, 18, 0, 0), 1),
#    (datetime.datetime(2018, 4, 19, 0, 0), 1),
#    (datetime.datetime(2018, 4, 20, 0, 0), 1),
#    (datetime.datetime(2018, 4, 21, 0, 0), 1),
#    (datetime.datetime(2018, 4, 22, 0, 0), 1),
#    (datetime.datetime(2018, 4, 23, 0, 0), 1),
#    (datetime.datetime(2018, 4, 24, 0, 0), 1),
#    (datetime.datetime(2018, 4, 25, 0, 0), 1),
#    (datetime.datetime(2018, 4, 26, 0, 0), 1),
#    (datetime.datetime(2018, 4, 27, 0, 0), 1),
#    (datetime.datetime(2018, 4, 28, 0, 0), 1),
#    (datetime.datetime(2018, 4, 29, 0, 0), 1),
#    (datetime.datetime(2018, 4, 30, 0, 0), 1),
#    (datetime.datetime(2018, 5, 1, 0, 0), 1),
#    (datetime.datetime(2018, 5, 2, 0, 0), 1),
#    (datetime.datetime(2018, 5, 3, 0, 0), 1),
#    (datetime.datetime(2018, 5, 4, 0, 0), 1),
#    (datetime.datetime(2018, 5, 5, 0, 0), 1),
#    (datetime.datetime(2018, 5, 6, 0, 0), 1),
#    (datetime.datetime(2018, 5, 7, 0, 0), 1),
#    (datetime.datetime(2018, 5, 8, 0, 0), 1),
#    (datetime.datetime(2018, 5, 9, 0, 0), 1),
#    (datetime.datetime(2018, 5, 10, 0, 0), 1),
#    (datetime.datetime(2018, 5, 11, 0, 0), 1),
#    (datetime.datetime(2018, 5, 12, 0, 0), 1),
#    (datetime.datetime(2018, 5, 13, 0, 0), 1),
#    (datetime.datetime(2018, 5, 14, 0, 0), 1),
#    (datetime.datetime(2018, 5, 15, 0, 0), 1),
#    (datetime.datetime(2018, 5, 16, 0, 0), 1),
#    (datetime.datetime(2018, 5, 17, 0, 0), 1),
#    (datetime.datetime(2018, 5, 18, 0, 0), 1),
#    (datetime.datetime(2018, 5, 19, 0, 0), 1),
#    (datetime.datetime(2018, 5, 20, 0, 0), 1),
#    (datetime.datetime(2018, 5, 21, 0, 0), 1),
#    (datetime.datetime(2018, 5, 22, 0, 0), 1),
#    (datetime.datetime(2018, 5, 23, 0, 0), 1),
#    (datetime.datetime(2018, 5, 24, 0, 0), 1),
#    (datetime.datetime(2018, 5, 25, 0, 0), 1),
#    (datetime.datetime(2018, 5, 26, 0, 0), 1),
#    (datetime.datetime(2018, 5, 27, 0, 0), 1),
#    (datetime.datetime(2018, 5, 28, 0, 0), 1),
#    (datetime.datetime(2018, 5, 29, 0, 0), 1),
#    (datetime.datetime(2018, 5, 30, 0, 0), 1),
#    (datetime.datetime(2018, 5, 31, 0, 0), 1),
#    (datetime.datetime(2018, 6, 1, 0, 0), 1),
#    (datetime.datetime(2018, 6, 2, 0, 0), 1),
#    (datetime.datetime(2018, 6, 3, 0, 0), 1),
#    (datetime.datetime(2018, 6, 4, 0, 0), 1),
#    (datetime.datetime(2018, 6, 5, 0, 0), 1),
#    (datetime.datetime(2018, 6, 6, 0, 0), 1),
#    (datetime.datetime(2018, 6, 7, 0, 0), 1),
#    (datetime.datetime(2018, 6, 8, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 5, 24, 0, 0), 1),
#    (datetime.datetime(2016, 5, 25, 0, 0), 1),
#    (datetime.datetime(2016, 5, 26, 0, 0), 1),
#    (datetime.datetime(2016, 5, 27, 0, 0), 1),
#    (datetime.datetime(2016, 5, 28, 0, 0), 1),
#    (datetime.datetime(2016, 5, 29, 0, 0), 1),
#    (datetime.datetime(2016, 5, 30, 0, 0), 1),
#    (datetime.datetime(2016, 5, 31, 0, 0), 1),
#    (datetime.datetime(2016, 6, 1, 0, 0), 1),
#    (datetime.datetime(2016, 6, 2, 0, 0), 1),
#    (datetime.datetime(2016, 6, 3, 0, 0), 1),
#    (datetime.datetime(2016, 6, 4, 0, 0), 1),
#    (datetime.datetime(2016, 6, 5, 0, 0), 1),
#    (datetime.datetime(2016, 6, 6, 0, 0), 1),
#    (datetime.datetime(2016, 6, 7, 0, 0), 1),
#    (datetime.datetime(2016, 6, 8, 0, 0), 1),
#    (datetime.datetime(2016, 6, 9, 0, 0), 1),
#    (datetime.datetime(2016, 6, 10, 0, 0), 1),
#    (datetime.datetime(2016, 6, 11, 0, 0), 1),
#    (datetime.datetime(2016, 6, 12, 0, 0), 1),
#    (datetime.datetime(2016, 6, 13, 0, 0), 1),
#    (datetime.datetime(2016, 6, 14, 0, 0), 1),
#    (datetime.datetime(2016, 6, 15, 0, 0), 1),
#    (datetime.datetime(2016, 6, 16, 0, 0), 1),
#    (datetime.datetime(2016, 6, 17, 0, 0), 1),
#    (datetime.datetime(2016, 6, 18, 0, 0), 1),
#    (datetime.datetime(2016, 6, 19, 0, 0), 1),
#    (datetime.datetime(2016, 6, 20, 0, 0), 1),
#    (datetime.datetime(2016, 6, 21, 0, 0), 1),
#    (datetime.datetime(2016, 6, 22, 0, 0), 1),
#    (datetime.datetime(2016, 6, 23, 0, 0), 1),
#    (datetime.datetime(2016, 6, 24, 0, 0), 1),
#    (datetime.datetime(2016, 6, 25, 0, 0), 1),
#    (datetime.datetime(2016, 6, 26, 0, 0), 1),
#    (datetime.datetime(2016, 6, 27, 0, 0), 1),
#    (datetime.datetime(2016, 6, 28, 0, 0), 1),
#    (datetime.datetime(2016, 6, 29, 0, 0), 1),
#    (datetime.datetime(2016, 6, 30, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 5, 9, 0, 0), 1),
#    (datetime.datetime(2017, 5, 10, 0, 0), 1),
#    (datetime.datetime(2017, 5, 11, 0, 0), 1),
#    (datetime.datetime(2017, 5, 12, 0, 0), 1),
#    (datetime.datetime(2017, 5, 13, 0, 0), 1),
#    (datetime.datetime(2017, 5, 14, 0, 0), 1),
#    (datetime.datetime(2017, 5, 15, 0, 0), 1),
#    (datetime.datetime(2017, 5, 16, 0, 0), 1),
#    (datetime.datetime(2017, 5, 17, 0, 0), 1),
#    (datetime.datetime(2017, 5, 18, 0, 0), 1),
#    (datetime.datetime(2017, 5, 19, 0, 0), 1),
#    (datetime.datetime(2017, 5, 20, 0, 0), 1),
#    (datetime.datetime(2017, 5, 21, 0, 0), 1),
#    (datetime.datetime(2017, 5, 22, 0, 0), 1),
#    (datetime.datetime(2017, 5, 23, 0, 0), 1),
#    (datetime.datetime(2017, 5, 24, 0, 0), 1),
#    (datetime.datetime(2017, 5, 25, 0, 0), 1),
#    (datetime.datetime(2017, 5, 26, 0, 0), 1),
#    (datetime.datetime(2017, 5, 27, 0, 0), 1),
#    (datetime.datetime(2017, 5, 28, 0, 0), 1),
#    (datetime.datetime(2017, 5, 29, 0, 0), 1),
#    (datetime.datetime(2017, 5, 30, 0, 0), 1),
#    (datetime.datetime(2017, 5, 31, 0, 0), 1),
#    (datetime.datetime(2017, 6, 1, 0, 0), 1),
#    (datetime.datetime(2017, 6, 2, 0, 0), 1),
#    (datetime.datetime(2017, 6, 3, 0, 0), 1),
#    (datetime.datetime(2017, 6, 4, 0, 0), 1),
#    (datetime.datetime(2017, 6, 5, 0, 0), 1),
#    (datetime.datetime(2017, 6, 6, 0, 0), 1),
#    (datetime.datetime(2017, 6, 7, 0, 0), 1),
#    (datetime.datetime(2017, 6, 8, 0, 0), 1),
#    (datetime.datetime(2017, 6, 9, 0, 0), 1),
#    (datetime.datetime(2017, 6, 10, 0, 0), 1),
#    (datetime.datetime(2017, 6, 11, 0, 0), 1),
#    (datetime.datetime(2017, 6, 12, 0, 0), 1),
#    (datetime.datetime(2017, 6, 13, 0, 0), 1),
#    (datetime.datetime(2017, 6, 14, 0, 0), 1),
#    (datetime.datetime(2017, 6, 15, 0, 0), 1),
#    (datetime.datetime(2017, 6, 16, 0, 0), 1),
#    (datetime.datetime(2017, 6, 17, 0, 0), 1),
#    (datetime.datetime(2017, 6, 18, 0, 0), 1),
#    (datetime.datetime(2017, 6, 19, 0, 0), 1),
#    (datetime.datetime(2017, 6, 20, 0, 0), 1),
#    (datetime.datetime(2017, 6, 21, 0, 0), 1),
#    (datetime.datetime(2017, 6, 22, 0, 0), 1),
#    (datetime.datetime(2017, 6, 23, 0, 0), 1),
#    (datetime.datetime(2017, 6, 24, 0, 0), 1),
#    (datetime.datetime(2017, 6, 25, 0, 0), 1),
#    (datetime.datetime(2017, 6, 26, 0, 0), 1),
#    (datetime.datetime(2017, 6, 27, 0, 0), 1),
#    (datetime.datetime(2017, 6, 28, 0, 0), 1),
#    (datetime.datetime(2017, 6, 29, 0, 0), 1),
#    (datetime.datetime(2017, 6, 30, 0, 0), 1),
#    (datetime.datetime(2017, 7, 1, 0, 0), 1),
#    (datetime.datetime(2017, 7, 2, 0, 0), 1),
#    (datetime.datetime(2017, 7, 3, 0, 0), 1),
#    (datetime.datetime(2017, 7, 4, 0, 0), 1),
#    (datetime.datetime(2017, 7, 5, 0, 0), 1),
#    (datetime.datetime(2017, 7, 6, 0, 0), 1),
#    (datetime.datetime(2017, 7, 7, 0, 0), 1),
#    (datetime.datetime(2017, 7, 8, 0, 0), 1),
#    (datetime.datetime(2017, 7, 9, 0, 0), 1),
#    (datetime.datetime(2017, 7, 10, 0, 0), 1),
#    (datetime.datetime(2017, 7, 11, 0, 0), 1),
#    (datetime.datetime(2017, 7, 12, 0, 0), 1),
#    (datetime.datetime(2017, 7, 13, 0, 0), 1),
#    (datetime.datetime(2017, 7, 14, 0, 0), 1),
#    (datetime.datetime(2017, 7, 15, 0, 0), 1),
#    (datetime.datetime(2017, 7, 16, 0, 0), 1),
#    (datetime.datetime(2017, 7, 17, 0, 0), 1),
#    (datetime.datetime(2017, 7, 18, 0, 0), 1),
#    (datetime.datetime(2017, 7, 19, 0, 0), 1),
#    (datetime.datetime(2017, 7, 20, 0, 0), 1),
#    (datetime.datetime(2017, 7, 21, 0, 0), 1),
#    (datetime.datetime(2017, 7, 22, 0, 0), 1),
#    (datetime.datetime(2017, 7, 23, 0, 0), 1),
#    (datetime.datetime(2017, 7, 24, 0, 0), 1),
#    (datetime.datetime(2017, 7, 25, 0, 0), 1),
#    (datetime.datetime(2017, 7, 26, 0, 0), 1),
#    (datetime.datetime(2017, 7, 27, 0, 0), 1),
#    (datetime.datetime(2017, 7, 28, 0, 0), 1),
#    (datetime.datetime(2017, 7, 29, 0, 0), 1),
#    (datetime.datetime(2017, 7, 30, 0, 0), 1),
#    (datetime.datetime(2017, 7, 31, 0, 0), 1),
#    (datetime.datetime(2017, 8, 1, 0, 0), 1),
#    (datetime.datetime(2017, 8, 2, 0, 0), 1),
#    (datetime.datetime(2017, 8, 3, 0, 0), 1),
#    (datetime.datetime(2017, 8, 4, 0, 0), 1),
#    (datetime.datetime(2017, 8, 5, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 10, 27, 0, 0), 1),
#    (datetime.datetime(2017, 10, 28, 0, 0), 1),
#    (datetime.datetime(2017, 10, 29, 0, 0), 1),
#    (datetime.datetime(2017, 10, 30, 0, 0), 1),
#    (datetime.datetime(2017, 10, 31, 0, 0), 1),
#    (datetime.datetime(2017, 11, 1, 0, 0), 1),
#    (datetime.datetime(2017, 11, 2, 0, 0), 1),
#    (datetime.datetime(2017, 11, 3, 0, 0), 1),
#    (datetime.datetime(2017, 11, 4, 0, 0), 1),
#    (datetime.datetime(2017, 11, 5, 0, 0), 1),
#    (datetime.datetime(2017, 11, 6, 0, 0), 1),
#    (datetime.datetime(2017, 11, 7, 0, 0), 1),
#    (datetime.datetime(2017, 11, 8, 0, 0), 1),
#    (datetime.datetime(2017, 11, 9, 0, 0), 1),
#    (datetime.datetime(2017, 11, 10, 0, 0), 1),
#    (datetime.datetime(2017, 11, 11, 0, 0), 1),
#    (datetime.datetime(2017, 11, 12, 0, 0), 1),
#    (datetime.datetime(2017, 11, 13, 0, 0), 1),
#    (datetime.datetime(2017, 11, 14, 0, 0), 1),
#    (datetime.datetime(2017, 11, 15, 0, 0), 1),
#    (datetime.datetime(2017, 11, 16, 0, 0), 1),
#    (datetime.datetime(2017, 11, 17, 0, 0), 1),
#    (datetime.datetime(2017, 11, 18, 0, 0), 1),
#    (datetime.datetime(2017, 11, 19, 0, 0), 1),
#    (datetime.datetime(2017, 11, 20, 0, 0), 1),
#    (datetime.datetime(2017, 11, 21, 0, 0), 1),
#    (datetime.datetime(2017, 11, 22, 0, 0), 1),
#    (datetime.datetime(2017, 11, 23, 0, 0), 1),
#    (datetime.datetime(2017, 11, 24, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 2, 15, 0, 0), 1),
#    (datetime.datetime(2016, 2, 16, 0, 0), 1),
#    (datetime.datetime(2016, 2, 17, 0, 0), 1),
#    (datetime.datetime(2016, 2, 18, 0, 0), 1),
#    (datetime.datetime(2016, 2, 19, 0, 0), 1),
#    (datetime.datetime(2016, 2, 20, 0, 0), 1),
#    (datetime.datetime(2016, 2, 21, 0, 0), 1),
#    (datetime.datetime(2016, 2, 22, 0, 0), 1),
#    (datetime.datetime(2016, 2, 23, 0, 0), 1),
#    (datetime.datetime(2016, 2, 24, 0, 0), 1),
#    (datetime.datetime(2016, 2, 25, 0, 0), 1),
#    (datetime.datetime(2016, 2, 26, 0, 0), 1),
#    (datetime.datetime(2016, 2, 27, 0, 0), 1),
#    (datetime.datetime(2016, 2, 28, 0, 0), 1),
#    (datetime.datetime(2016, 2, 29, 0, 0), 1),
#    (datetime.datetime(2016, 3, 1, 0, 0), 1),
#    (datetime.datetime(2016, 3, 2, 0, 0), 1),
#    (datetime.datetime(2016, 3, 3, 0, 0), 1),
#    (datetime.datetime(2016, 3, 4, 0, 0), 1),
#    (datetime.datetime(2016, 3, 5, 0, 0), 1),
#    (datetime.datetime(2016, 3, 6, 0, 0), 1),
#    (datetime.datetime(2016, 3, 7, 0, 0), 1),
#    (datetime.datetime(2016, 3, 8, 0, 0), 1),
#    (datetime.datetime(2016, 3, 9, 0, 0), 1),
#    (datetime.datetime(2016, 3, 10, 0, 0), 1),
#    (datetime.datetime(2016, 3, 11, 0, 0), 1),
#    (datetime.datetime(2016, 3, 12, 0, 0), 1),
#    (datetime.datetime(2016, 3, 13, 0, 0), 1),
#    (datetime.datetime(2016, 3, 14, 0, 0), 1),
#    (datetime.datetime(2016, 3, 15, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 4, 7, 0, 0), 1),
#    (datetime.datetime(2016, 4, 8, 0, 0), 1),
#    (datetime.datetime(2016, 4, 9, 0, 0), 1),
#    (datetime.datetime(2016, 4, 10, 0, 0), 1),
#    (datetime.datetime(2016, 4, 11, 0, 0), 1),
#    (datetime.datetime(2016, 4, 12, 0, 0), 1),
#    (datetime.datetime(2016, 4, 13, 0, 0), 1),
#    (datetime.datetime(2016, 4, 14, 0, 0), 1),
#    (datetime.datetime(2016, 4, 15, 0, 0), 1),
#    (datetime.datetime(2016, 4, 16, 0, 0), 1),
#    (datetime.datetime(2016, 4, 17, 0, 0), 1),
#    (datetime.datetime(2016, 4, 18, 0, 0), 1),
#    (datetime.datetime(2016, 4, 19, 0, 0), 1),
#    (datetime.datetime(2016, 4, 20, 0, 0), 1),
#    (datetime.datetime(2016, 4, 21, 0, 0), 1),
#    (datetime.datetime(2016, 4, 22, 0, 0), 1),
#    (datetime.datetime(2016, 4, 23, 0, 0), 1),
#    (datetime.datetime(2016, 4, 24, 0, 0), 1),
#    (datetime.datetime(2016, 4, 25, 0, 0), 1),
#    (datetime.datetime(2016, 4, 26, 0, 0), 1),
#    (datetime.datetime(2016, 4, 27, 0, 0), 1),
#    (datetime.datetime(2016, 4, 28, 0, 0), 1),
#    (datetime.datetime(2016, 4, 29, 0, 0), 1),
#    (datetime.datetime(2016, 4, 30, 0, 0), 1),
#    (datetime.datetime(2016, 5, 1, 0, 0), 1),
#    (datetime.datetime(2016, 5, 2, 0, 0), 1),
#    (datetime.datetime(2016, 5, 3, 0, 0), 1),
#    (datetime.datetime(2016, 5, 4, 0, 0), 1),
#    (datetime.datetime(2016, 5, 5, 0, 0), 1),
#    (datetime.datetime(2016, 5, 6, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 9, 11, 0, 0), 1),
#    (datetime.datetime(2017, 9, 12, 0, 0), 1),
#    (datetime.datetime(2017, 9, 13, 0, 0), 1),
#    (datetime.datetime(2017, 9, 14, 0, 0), 1),
#    (datetime.datetime(2017, 9, 15, 0, 0), 1),
#    (datetime.datetime(2017, 9, 16, 0, 0), 1),
#    (datetime.datetime(2017, 9, 17, 0, 0), 1),
#    (datetime.datetime(2017, 9, 18, 0, 0), 1),
#    (datetime.datetime(2017, 9, 19, 0, 0), 1),
#    (datetime.datetime(2017, 9, 20, 0, 0), 1),
#    (datetime.datetime(2017, 9, 21, 0, 0), 1),
#    (datetime.datetime(2017, 9, 22, 0, 0), 1),
#    (datetime.datetime(2017, 9, 23, 0, 0), 1),
#    (datetime.datetime(2017, 9, 24, 0, 0), 1),
#    (datetime.datetime(2017, 9, 25, 0, 0), 1),
#    (datetime.datetime(2017, 9, 26, 0, 0), 1),
#    (datetime.datetime(2017, 9, 27, 0, 0), 1),
#    (datetime.datetime(2017, 9, 28, 0, 0), 1),
#    (datetime.datetime(2017, 9, 29, 0, 0), 1),
#    (datetime.datetime(2017, 9, 30, 0, 0), 1),
#    (datetime.datetime(2017, 10, 1, 0, 0), 1),
#    (datetime.datetime(2017, 10, 2, 0, 0), 1),
#    (datetime.datetime(2017, 10, 3, 0, 0), 1),
#    (datetime.datetime(2017, 10, 4, 0, 0), 1),
#    (datetime.datetime(2017, 10, 5, 0, 0), 1),
#    (datetime.datetime(2017, 10, 6, 0, 0), 1),
#    (datetime.datetime(2017, 10, 7, 0, 0), 1),
#    (datetime.datetime(2017, 10, 8, 0, 0), 1),
#    (datetime.datetime(2017, 10, 9, 0, 0), 1),
#    (datetime.datetime(2017, 10, 10, 0, 0), 1),
#    (datetime.datetime(2017, 10, 11, 0, 0), 1),
#    (datetime.datetime(2017, 10, 12, 0, 0), 1),
#    (datetime.datetime(2017, 10, 13, 0, 0), 1),
#    (datetime.datetime(2017, 10, 14, 0, 0), 1),
#    (datetime.datetime(2017, 10, 15, 0, 0), 1),
#    (datetime.datetime(2017, 10, 16, 0, 0), 1),
#    (datetime.datetime(2017, 10, 17, 0, 0), 1),
#    (datetime.datetime(2017, 10, 18, 0, 0), 1),
#    (datetime.datetime(2017, 10, 19, 0, 0), 1),
#    (datetime.datetime(2017, 10, 20, 0, 0), 1),
#    (datetime.datetime(2017, 10, 21, 0, 0), 1),
#    (datetime.datetime(2017, 10, 22, 0, 0), 1),
#    (datetime.datetime(2017, 10, 23, 0, 0), 1),
#    (datetime.datetime(2017, 10, 24, 0, 0), 1),
#    (datetime.datetime(2017, 10, 25, 0, 0), 1),
#    (datetime.datetime(2017, 10, 26, 0, 0), 1),
#    (datetime.datetime(2017, 10, 27, 0, 0), 1),
#    (datetime.datetime(2017, 10, 28, 0, 0), 1),
#    (datetime.datetime(2017, 10, 29, 0, 0), 1),
#    (datetime.datetime(2017, 10, 30, 0, 0), 1),
#    (datetime.datetime(2017, 10, 31, 0, 0), 1),
#    (datetime.datetime(2017, 11, 1, 0, 0), 1),
#    (datetime.datetime(2017, 11, 2, 0, 0), 1),
#    (datetime.datetime(2017, 11, 3, 0, 0), 1),
#    (datetime.datetime(2017, 11, 4, 0, 0), 1),
#    (datetime.datetime(2017, 11, 5, 0, 0), 1),
#    (datetime.datetime(2017, 11, 6, 0, 0), 1),
#    (datetime.datetime(2017, 11, 7, 0, 0), 1),
#    (datetime.datetime(2017, 11, 8, 0, 0), 1),
#    (datetime.datetime(2017, 11, 9, 0, 0), 1),
#    (datetime.datetime(2017, 11, 10, 0, 0), 1),
#    (datetime.datetime(2017, 11, 11, 0, 0), 1),
#    (datetime.datetime(2017, 11, 12, 0, 0), 1),
#    (datetime.datetime(2017, 11, 13, 0, 0), 1),
#    (datetime.datetime(2017, 11, 14, 0, 0), 1),
#    (datetime.datetime(2017, 11, 15, 0, 0), 1),
#    (datetime.datetime(2017, 11, 16, 0, 0), 1),
#    (datetime.datetime(2017, 11, 17, 0, 0), 1),
#    (datetime.datetime(2017, 11, 18, 0, 0), 1),
#    (datetime.datetime(2017, 11, 19, 0, 0), 1),
#    (datetime.datetime(2017, 11, 20, 0, 0), 1),
#    (datetime.datetime(2017, 11, 21, 0, 0), 1),
#    (datetime.datetime(2017, 11, 22, 0, 0), 1),
#    (datetime.datetime(2017, 11, 23, 0, 0), 1),
#    (datetime.datetime(2017, 11, 24, 0, 0), 1),
#    (datetime.datetime(2017, 11, 25, 0, 0), 1),
#    (datetime.datetime(2017, 11, 26, 0, 0), 1),
#    (datetime.datetime(2017, 11, 27, 0, 0), 1),
#    (datetime.datetime(2017, 11, 28, 0, 0), 1),
#    (datetime.datetime(2017, 11, 29, 0, 0), 1),
#    (datetime.datetime(2017, 11, 30, 0, 0), 1),
#    (datetime.datetime(2017, 12, 1, 0, 0), 1),
#    (datetime.datetime(2017, 12, 2, 0, 0), 1),
#    (datetime.datetime(2017, 12, 3, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 11, 29, 0, 0), 1),
#    (datetime.datetime(2016, 11, 30, 0, 0), 1),
#    (datetime.datetime(2016, 12, 1, 0, 0), 1),
#    (datetime.datetime(2016, 12, 2, 0, 0), 1),
#    (datetime.datetime(2016, 12, 3, 0, 0), 1),
#    (datetime.datetime(2016, 12, 4, 0, 0), 1),
#    (datetime.datetime(2016, 12, 5, 0, 0), 1),
#    (datetime.datetime(2016, 12, 6, 0, 0), 1),
#    (datetime.datetime(2016, 12, 7, 0, 0), 1),
#    (datetime.datetime(2016, 12, 8, 0, 0), 1),
#    (datetime.datetime(2016, 12, 9, 0, 0), 1),
#    (datetime.datetime(2016, 12, 10, 0, 0), 1),
#    (datetime.datetime(2016, 12, 11, 0, 0), 1),
#    (datetime.datetime(2016, 12, 12, 0, 0), 1),
#    (datetime.datetime(2016, 12, 13, 0, 0), 1),
#    (datetime.datetime(2016, 12, 14, 0, 0), 1),
#    (datetime.datetime(2016, 12, 15, 0, 0), 1),
#    (datetime.datetime(2016, 12, 16, 0, 0), 1),
#    (datetime.datetime(2016, 12, 17, 0, 0), 1),
#    (datetime.datetime(2016, 12, 18, 0, 0), 1),
#    (datetime.datetime(2016, 12, 19, 0, 0), 1),
#    (datetime.datetime(2016, 12, 20, 0, 0), 1),
#    (datetime.datetime(2016, 12, 21, 0, 0), 1),
#    (datetime.datetime(2016, 12, 22, 0, 0), 1),
#    (datetime.datetime(2016, 12, 23, 0, 0), 1),
#    (datetime.datetime(2016, 12, 24, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 12, 21, 0, 0), 1),
#    (datetime.datetime(2016, 12, 22, 0, 0), 1),
#    (datetime.datetime(2016, 12, 23, 0, 0), 1),
#    (datetime.datetime(2016, 12, 24, 0, 0), 1),
#    (datetime.datetime(2016, 12, 25, 0, 0), 1),
#    (datetime.datetime(2016, 12, 26, 0, 0), 1),
#    (datetime.datetime(2016, 12, 27, 0, 0), 1),
#    (datetime.datetime(2016, 12, 28, 0, 0), 1),
#    (datetime.datetime(2016, 12, 29, 0, 0), 1),
#    (datetime.datetime(2016, 12, 30, 0, 0), 1),
#    (datetime.datetime(2016, 12, 31, 0, 0), 1),
#    (datetime.datetime(2017, 1, 1, 0, 0), 1),
#    (datetime.datetime(2017, 1, 2, 0, 0), 1),
#    (datetime.datetime(2017, 1, 3, 0, 0), 1),
#    (datetime.datetime(2017, 1, 4, 0, 0), 1),
#    (datetime.datetime(2017, 1, 5, 0, 0), 1),
#    (datetime.datetime(2017, 1, 6, 0, 0), 1),
#    (datetime.datetime(2017, 1, 7, 0, 0), 1),
#    (datetime.datetime(2017, 1, 8, 0, 0), 1),
#    (datetime.datetime(2017, 1, 9, 0, 0), 1),
#    (datetime.datetime(2017, 1, 10, 0, 0), 1),
#    (datetime.datetime(2017, 1, 11, 0, 0), 1),
#    (datetime.datetime(2017, 1, 12, 0, 0), 1),
#    (datetime.datetime(2017, 1, 13, 0, 0), 1),
#    (datetime.datetime(2017, 1, 14, 0, 0), 1),
#    (datetime.datetime(2017, 1, 15, 0, 0), 1),
#    (datetime.datetime(2017, 1, 16, 0, 0), 1),
#    (datetime.datetime(2017, 1, 17, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 12, 2, 0, 0), 1),
#    (datetime.datetime(2016, 12, 3, 0, 0), 1),
#    (datetime.datetime(2016, 12, 4, 0, 0), 1),
#    (datetime.datetime(2016, 12, 5, 0, 0), 1),
#    (datetime.datetime(2016, 12, 6, 0, 0), 1),
#    (datetime.datetime(2016, 12, 7, 0, 0), 1),
#    (datetime.datetime(2016, 12, 8, 0, 0), 1),
#    (datetime.datetime(2016, 12, 9, 0, 0), 1),
#    (datetime.datetime(2016, 12, 10, 0, 0), 1),
#    (datetime.datetime(2016, 12, 11, 0, 0), 1),
#    (datetime.datetime(2016, 12, 12, 0, 0), 1),
#    (datetime.datetime(2016, 12, 13, 0, 0), 1),
#    (datetime.datetime(2016, 12, 14, 0, 0), 1),
#    (datetime.datetime(2016, 12, 15, 0, 0), 1),
#    (datetime.datetime(2016, 12, 16, 0, 0), 1),
#    (datetime.datetime(2016, 12, 17, 0, 0), 1),
#    (datetime.datetime(2016, 12, 18, 0, 0), 1),
#    (datetime.datetime(2016, 12, 19, 0, 0), 1),
#    (datetime.datetime(2016, 12, 20, 0, 0), 1),
#    (datetime.datetime(2016, 12, 21, 0, 0), 1),
#    (datetime.datetime(2016, 12, 22, 0, 0), 1),
#    (datetime.datetime(2016, 12, 23, 0, 0), 1),
#    (datetime.datetime(2016, 12, 24, 0, 0), 1),
#    (datetime.datetime(2016, 12, 25, 0, 0), 1),
#    (datetime.datetime(2016, 12, 26, 0, 0), 1),
#    (datetime.datetime(2016, 12, 27, 0, 0), 1),
#    (datetime.datetime(2016, 12, 28, 0, 0), 1),
#    (datetime.datetime(2016, 12, 29, 0, 0), 1),
#    (datetime.datetime(2016, 12, 30, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 9, 28, 0, 0), 1),
#    (datetime.datetime(2016, 9, 29, 0, 0), 1),
#    (datetime.datetime(2016, 9, 30, 0, 0), 1),
#    (datetime.datetime(2016, 10, 1, 0, 0), 1),
#    (datetime.datetime(2016, 10, 2, 0, 0), 1),
#    (datetime.datetime(2016, 10, 3, 0, 0), 1),
#    (datetime.datetime(2016, 10, 4, 0, 0), 1),
#    (datetime.datetime(2016, 10, 5, 0, 0), 1),
#    (datetime.datetime(2016, 10, 6, 0, 0), 1),
#    (datetime.datetime(2016, 10, 7, 0, 0), 1),
#    (datetime.datetime(2016, 10, 8, 0, 0), 1),
#    (datetime.datetime(2016, 10, 9, 0, 0), 1),
#    (datetime.datetime(2016, 10, 10, 0, 0), 1),
#    (datetime.datetime(2016, 10, 11, 0, 0), 1),
#    (datetime.datetime(2016, 10, 12, 0, 0), 1),
#    (datetime.datetime(2016, 10, 13, 0, 0), 1),
#    (datetime.datetime(2016, 10, 14, 0, 0), 1),
#    (datetime.datetime(2016, 10, 15, 0, 0), 1),
#    (datetime.datetime(2016, 10, 16, 0, 0), 1),
#    (datetime.datetime(2016, 10, 17, 0, 0), 1),
#    (datetime.datetime(2016, 10, 18, 0, 0), 1),
#    (datetime.datetime(2016, 10, 19, 0, 0), 1),
#    (datetime.datetime(2016, 10, 20, 0, 0), 1),
#    (datetime.datetime(2016, 10, 21, 0, 0), 1),
#    (datetime.datetime(2016, 10, 22, 0, 0), 1),
#    (datetime.datetime(2016, 10, 23, 0, 0), 1),
#    (datetime.datetime(2016, 10, 24, 0, 0), 1),
#    (datetime.datetime(2016, 10, 25, 0, 0), 1),
#    (datetime.datetime(2016, 10, 26, 0, 0), 1),
#    (datetime.datetime(2016, 10, 27, 0, 0), 1),
#    (datetime.datetime(2016, 10, 28, 0, 0), 1),
#    (datetime.datetime(2016, 10, 29, 0, 0), 1),
#    (datetime.datetime(2016, 10, 30, 0, 0), 1),
#    (datetime.datetime(2016, 10, 31, 0, 0), 1),
#    (datetime.datetime(2016, 11, 1, 0, 0), 1),
#    (datetime.datetime(2016, 11, 2, 0, 0), 1),
#    (datetime.datetime(2016, 11, 3, 0, 0), 1),
#    (datetime.datetime(2016, 11, 4, 0, 0), 1),
#    (datetime.datetime(2016, 11, 5, 0, 0), 1),
#    (datetime.datetime(2016, 11, 6, 0, 0), 1),
#    (datetime.datetime(2016, 11, 7, 0, 0), 1),
#    (datetime.datetime(2016, 11, 8, 0, 0), 1),
#    (datetime.datetime(2016, 11, 9, 0, 0), 1),
#    (datetime.datetime(2016, 11, 10, 0, 0), 1),
#    (datetime.datetime(2016, 11, 11, 0, 0), 1),
#    (datetime.datetime(2016, 11, 12, 0, 0), 1),
#    (datetime.datetime(2016, 11, 13, 0, 0), 1),
#    (datetime.datetime(2016, 11, 14, 0, 0), 1),
#    (datetime.datetime(2016, 11, 15, 0, 0), 1),
#    (datetime.datetime(2016, 11, 16, 0, 0), 1),
#    (datetime.datetime(2016, 11, 17, 0, 0), 1),
#    (datetime.datetime(2016, 11, 18, 0, 0), 1),
#    (datetime.datetime(2016, 11, 19, 0, 0), 1),
#    (datetime.datetime(2016, 11, 20, 0, 0), 1),
#    (datetime.datetime(2016, 11, 21, 0, 0), 1),
#    (datetime.datetime(2016, 11, 22, 0, 0), 1),
#    (datetime.datetime(2016, 11, 23, 0, 0), 1),
#    (datetime.datetime(2016, 11, 24, 0, 0), 1),
#    (datetime.datetime(2016, 11, 25, 0, 0), 1),
#    (datetime.datetime(2016, 11, 26, 0, 0), 1),
#    (datetime.datetime(2016, 11, 27, 0, 0), 1),
#    (datetime.datetime(2016, 11, 28, 0, 0), 1),
#    (datetime.datetime(2016, 11, 29, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 6, 7, 0, 0), 1),
#    (datetime.datetime(2017, 6, 8, 0, 0), 1),
#    (datetime.datetime(2017, 6, 9, 0, 0), 1),
#    (datetime.datetime(2017, 6, 10, 0, 0), 1),
#    (datetime.datetime(2017, 6, 11, 0, 0), 1),
#    (datetime.datetime(2017, 6, 12, 0, 0), 1),
#    (datetime.datetime(2017, 6, 13, 0, 0), 1),
#    (datetime.datetime(2017, 6, 14, 0, 0), 1),
#    (datetime.datetime(2017, 6, 15, 0, 0), 1),
#    (datetime.datetime(2017, 6, 16, 0, 0), 1),
#    (datetime.datetime(2017, 6, 17, 0, 0), 1),
#    (datetime.datetime(2017, 6, 18, 0, 0), 1),
#    (datetime.datetime(2017, 6, 19, 0, 0), 1),
#    (datetime.datetime(2017, 6, 20, 0, 0), 1),
#    (datetime.datetime(2017, 6, 21, 0, 0), 1),
#    (datetime.datetime(2017, 6, 22, 0, 0), 1),
#    (datetime.datetime(2017, 6, 23, 0, 0), 1),
#    (datetime.datetime(2017, 6, 24, 0, 0), 1),
#    (datetime.datetime(2017, 6, 25, 0, 0), 1),
#    (datetime.datetime(2017, 6, 26, 0, 0), 1),
#    (datetime.datetime(2017, 6, 27, 0, 0), 1),
#    (datetime.datetime(2017, 6, 28, 0, 0), 1),
#    (datetime.datetime(2017, 6, 29, 0, 0), 1),
#    (datetime.datetime(2017, 6, 30, 0, 0), 1),
#    (datetime.datetime(2017, 7, 1, 0, 0), 1),
#    (datetime.datetime(2017, 7, 2, 0, 0), 1),
#    (datetime.datetime(2017, 7, 3, 0, 0), 1),
#    (datetime.datetime(2017, 7, 4, 0, 0), 1),
#    (datetime.datetime(2017, 7, 5, 0, 0), 1),
#    (datetime.datetime(2017, 7, 6, 0, 0), 1),
#    (datetime.datetime(2017, 7, 7, 0, 0), 1),
#    (datetime.datetime(2017, 7, 8, 0, 0), 1),
#    (datetime.datetime(2017, 7, 9, 0, 0), 1),
#    (datetime.datetime(2017, 7, 10, 0, 0), 1),
#    (datetime.datetime(2017, 7, 11, 0, 0), 1),
#    (datetime.datetime(2017, 7, 12, 0, 0), 1),
#    (datetime.datetime(2017, 7, 13, 0, 0), 1),
#    (datetime.datetime(2017, 7, 14, 0, 0), 1),
#    (datetime.datetime(2017, 7, 15, 0, 0), 1),
#    (datetime.datetime(2017, 7, 16, 0, 0), 1),
#    (datetime.datetime(2017, 7, 17, 0, 0), 1),
#    (datetime.datetime(2017, 7, 18, 0, 0), 1),
#    (datetime.datetime(2017, 7, 19, 0, 0), 1),
#    (datetime.datetime(2017, 7, 20, 0, 0), 1),
#    (datetime.datetime(2017, 7, 21, 0, 0), 1),
#    (datetime.datetime(2017, 7, 22, 0, 0), 1),
#    (datetime.datetime(2017, 7, 23, 0, 0), 1),
#    (datetime.datetime(2017, 7, 24, 0, 0), 1),
#    (datetime.datetime(2017, 7, 25, 0, 0), 1),
#    (datetime.datetime(2017, 7, 26, 0, 0), 1),
#    (datetime.datetime(2017, 7, 27, 0, 0), 1),
#    (datetime.datetime(2017, 7, 28, 0, 0), 1),
#    (datetime.datetime(2017, 7, 29, 0, 0), 1),
#    (datetime.datetime(2017, 7, 30, 0, 0), 1),
#    (datetime.datetime(2017, 7, 31, 0, 0), 1),
#    (datetime.datetime(2017, 8, 1, 0, 0), 1),
#    (datetime.datetime(2017, 8, 2, 0, 0), 1),
#    (datetime.datetime(2017, 8, 3, 0, 0), 1),
#    (datetime.datetime(2017, 8, 4, 0, 0), 1),
#    (datetime.datetime(2017, 8, 5, 0, 0), 1),
#    (datetime.datetime(2017, 8, 6, 0, 0), 1),
#    (datetime.datetime(2017, 8, 7, 0, 0), 1),
#    (datetime.datetime(2017, 8, 8, 0, 0), 1),
#    (datetime.datetime(2017, 8, 9, 0, 0), 1),
#    (datetime.datetime(2017, 8, 10, 0, 0), 1),
#    (datetime.datetime(2017, 8, 11, 0, 0), 1),
#    (datetime.datetime(2017, 8, 12, 0, 0), 1),
#    (datetime.datetime(2017, 8, 13, 0, 0), 1),
#    (datetime.datetime(2017, 8, 14, 0, 0), 1),
#    (datetime.datetime(2017, 8, 15, 0, 0), 1),
#    (datetime.datetime(2017, 8, 16, 0, 0), 1),
#    (datetime.datetime(2017, 8, 17, 0, 0), 1),
#    (datetime.datetime(2017, 8, 18, 0, 0), 1),
#    (datetime.datetime(2017, 8, 19, 0, 0), 1),
#    (datetime.datetime(2017, 8, 20, 0, 0), 1),
#    (datetime.datetime(2017, 8, 21, 0, 0), 1),
#    (datetime.datetime(2017, 8, 22, 0, 0), 1),
#    (datetime.datetime(2017, 8, 23, 0, 0), 1),
#    (datetime.datetime(2017, 8, 24, 0, 0), 1),
#    (datetime.datetime(2017, 8, 25, 0, 0), 1),
#    (datetime.datetime(2017, 8, 26, 0, 0), 1),
#    (datetime.datetime(2017, 8, 27, 0, 0), 1),
#    (datetime.datetime(2017, 8, 28, 0, 0), 1),
#    (datetime.datetime(2017, 8, 29, 0, 0), 1),
#    (datetime.datetime(2017, 8, 30, 0, 0), 1),
#    (datetime.datetime(2017, 8, 31, 0, 0), 1),
#    (datetime.datetime(2017, 9, 1, 0, 0), 1),
#    (datetime.datetime(2017, 9, 2, 0, 0), 1),
#    (datetime.datetime(2017, 9, 3, 0, 0), 1),
#    (datetime.datetime(2017, 9, 4, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2017, 12, 7, 0, 0), 1),
#    (datetime.datetime(2017, 12, 8, 0, 0), 1),
#    (datetime.datetime(2017, 12, 9, 0, 0), 1),
#    (datetime.datetime(2017, 12, 10, 0, 0), 1),
#    (datetime.datetime(2017, 12, 11, 0, 0), 1),
#    (datetime.datetime(2017, 12, 12, 0, 0), 1),
#    (datetime.datetime(2017, 12, 13, 0, 0), 1),
#    (datetime.datetime(2017, 12, 14, 0, 0), 1),
#    (datetime.datetime(2017, 12, 15, 0, 0), 1),
#    (datetime.datetime(2017, 12, 16, 0, 0), 1),
#    (datetime.datetime(2017, 12, 17, 0, 0), 1),
#    (datetime.datetime(2017, 12, 18, 0, 0), 1),
#    (datetime.datetime(2017, 12, 19, 0, 0), 1),
#    (datetime.datetime(2017, 12, 20, 0, 0), 1),
#    (datetime.datetime(2017, 12, 21, 0, 0), 1),
#    (datetime.datetime(2017, 12, 22, 0, 0), 1),
#    (datetime.datetime(2017, 12, 23, 0, 0), 1),
#    (datetime.datetime(2017, 12, 24, 0, 0), 1),
#    (datetime.datetime(2017, 12, 25, 0, 0), 1),
#    (datetime.datetime(2017, 12, 26, 0, 0), 1),
#    (datetime.datetime(2017, 12, 27, 0, 0), 1),
#    (datetime.datetime(2017, 12, 28, 0, 0), 1),
#    (datetime.datetime(2017, 12, 29, 0, 0), 1),
#    (datetime.datetime(2017, 12, 30, 0, 0), 1),
#    (datetime.datetime(2017, 12, 31, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 8, 29, 0, 0), 1),
#    (datetime.datetime(2016, 8, 30, 0, 0), 1),
#    (datetime.datetime(2016, 8, 31, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2018, 1, 2, 0, 0), 1),
#    (datetime.datetime(2018, 1, 3, 0, 0), 1),
#    (datetime.datetime(2018, 1, 4, 0, 0), 1),
#    (datetime.datetime(2018, 1, 5, 0, 0), 1),
#    (datetime.datetime(2018, 1, 6, 0, 0), 1),
#    (datetime.datetime(2018, 1, 7, 0, 0), 1),
#    (datetime.datetime(2018, 1, 8, 0, 0), 1),
#    (datetime.datetime(2018, 1, 9, 0, 0), 1),
#    (datetime.datetime(2018, 1, 10, 0, 0), 1),
#    (datetime.datetime(2018, 1, 11, 0, 0), 1),
#    (datetime.datetime(2018, 1, 12, 0, 0), 1),
#    (datetime.datetime(2018, 1, 13, 0, 0), 1),
#    (datetime.datetime(2018, 1, 14, 0, 0), 1),
#    (datetime.datetime(2018, 1, 15, 0, 0), 1),
#    (datetime.datetime(2018, 1, 16, 0, 0), 1),
#    (datetime.datetime(2018, 1, 17, 0, 0), 1),
#    (datetime.datetime(2018, 1, 18, 0, 0), 1),
#    (datetime.datetime(2018, 1, 19, 0, 0), 1),
#    (datetime.datetime(2018, 1, 20, 0, 0), 1),
#    (datetime.datetime(2018, 1, 21, 0, 0), 1),
#    (datetime.datetime(2018, 1, 22, 0, 0), 1),
#    (datetime.datetime(2018, 1, 23, 0, 0), 1),
#    (datetime.datetime(2018, 1, 24, 0, 0), 1),
#    (datetime.datetime(2018, 1, 25, 0, 0), 1),
#    (datetime.datetime(2018, 1, 26, 0, 0), 1),
#    (datetime.datetime(2018, 1, 27, 0, 0), 1),
#    (datetime.datetime(2018, 1, 28, 0, 0), 1),
#    (datetime.datetime(2018, 1, 29, 0, 0), 1),
#    (datetime.datetime(2018, 1, 30, 0, 0), 1),
#    (datetime.datetime(2018, 1, 31, 0, 0), 1),
#    (datetime.datetime(2018, 2, 1, 0, 0), 1),
#    (datetime.datetime(2018, 2, 2, 0, 0), 1),
#    (datetime.datetime(2018, 2, 3, 0, 0), 1),
#    (datetime.datetime(2018, 2, 4, 0, 0), 1),
#    (datetime.datetime(2018, 2, 5, 0, 0), 1),
#    (datetime.datetime(2018, 2, 6, 0, 0), 1),
#    (datetime.datetime(2018, 2, 7, 0, 0), 1),
#    (datetime.datetime(2018, 2, 8, 0, 0), 1),
#    (datetime.datetime(2018, 2, 9, 0, 0), 1),
#    (datetime.datetime(2018, 2, 10, 0, 0), 1),
#    (datetime.datetime(2018, 2, 11, 0, 0), 1),
#    (datetime.datetime(2018, 2, 12, 0, 0), 1),
#    (datetime.datetime(2018, 2, 13, 0, 0), 1),
#    (datetime.datetime(2018, 2, 14, 0, 0), 1),
#    (datetime.datetime(2018, 2, 15, 0, 0), 1),
#    (datetime.datetime(2018, 2, 16, 0, 0), 1),
#    (datetime.datetime(2018, 2, 17, 0, 0), 1),
#    (datetime.datetime(2018, 2, 18, 0, 0), 1),
#    (datetime.datetime(2018, 2, 19, 0, 0), 1),
#    (datetime.datetime(2018, 2, 20, 0, 0), 1),
#    (datetime.datetime(2018, 2, 21, 0, 0), 1),
#    (datetime.datetime(2018, 2, 22, 0, 0), 1),
#    (datetime.datetime(2018, 2, 23, 0, 0), 1),
#    (datetime.datetime(2018, 2, 24, 0, 0), 1),
#    (datetime.datetime(2018, 2, 25, 0, 0), 1),
#    (datetime.datetime(2018, 2, 26, 0, 0), 1),
#    (datetime.datetime(2018, 2, 27, 0, 0), 1),
#    (datetime.datetime(2018, 2, 28, 0, 0), 1),
#    (datetime.datetime(2018, 3, 1, 0, 0), 1),
#    (datetime.datetime(2018, 3, 2, 0, 0), 1),
#    (datetime.datetime(2018, 3, 3, 0, 0), 1),
#    (datetime.datetime(2018, 3, 4, 0, 0), 1),
#    (datetime.datetime(2018, 3, 5, 0, 0), 1),
#    (datetime.datetime(2018, 3, 6, 0, 0), 1),
#    (datetime.datetime(2018, 3, 7, 0, 0), 1),
#    (datetime.datetime(2018, 3, 8, 0, 0), 1),
#    (datetime.datetime(2018, 3, 9, 0, 0), 1),
#    (datetime.datetime(2018, 3, 10, 0, 0), 1),
#    (datetime.datetime(2018, 3, 11, 0, 0), 1),
#    (datetime.datetime(2018, 3, 12, 0, 0), 1),
#    (datetime.datetime(2018, 3, 13, 0, 0), 1),
#    (datetime.datetime(2018, 3, 14, 0, 0), 1),
#    (datetime.datetime(2018, 3, 15, 0, 0), 1),
#    (datetime.datetime(2018, 3, 16, 0, 0), 1),
#    (datetime.datetime(2018, 3, 17, 0, 0), 1),
#    (datetime.datetime(2018, 3, 18, 0, 0), 1),
#    (datetime.datetime(2018, 3, 19, 0, 0), 1),
#    (datetime.datetime(2018, 3, 20, 0, 0), 1),
#    (datetime.datetime(2018, 3, 21, 0, 0), 1),
#    (datetime.datetime(2018, 3, 22, 0, 0), 1),
#    (datetime.datetime(2018, 3, 23, 0, 0), 1),
#    (datetime.datetime(2018, 3, 24, 0, 0), 1),
#    (datetime.datetime(2018, 3, 25, 0, 0), 1),
#    (datetime.datetime(2018, 3, 26, 0, 0), 1),
#    (datetime.datetime(2018, 3, 27, 0, 0), 1),
#    (datetime.datetime(2018, 3, 28, 0, 0), 1),
#    (datetime.datetime(2018, 3, 29, 0, 0), 1),
#    (datetime.datetime(2018, 3, 30, 0, 0), 1),
#    (datetime.datetime(2018, 3, 31, 0, 0), 1),
#    (datetime.datetime(2018, 4, 1, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 1, 26, 0, 0), 1),
#    (datetime.datetime(2016, 1, 27, 0, 0), 1),
#    (datetime.datetime(2016, 1, 28, 0, 0), 1),
#    (datetime.datetime(2016, 1, 29, 0, 0), 1),
#    (datetime.datetime(2016, 1, 30, 0, 0), 1),
#    ('BROOKLYN', 'QUENTIN ROAD'),
#    (datetime.datetime(2016, 3, 11, 0, 0), 1),
#    (datetime.datetime(2016, 3, 12, 0, 0), 1),
#    (datetime.datetime(2016, 3, 13, 0, 0), 1),
#    (datetime.datetime(2016, 3, 14, 0, 0), 1),
#    (datetime.datetime(2016, 3, 15, 0, 0), 1),
#    (datetime.datetime(2016, 3, 16, 0, 0), 1),
#    (datetime.datetime(2016, 3, 17, 0, 0), 1),
#    (datetime.datetime(2016, 3, 18, 0, 0), 1),
#    (datetime.datetime(2016, 3, 19, 0, 0), 1),
#    (datetime.datetime(2016, 3, 20, 0, 0), 1),
#    (datetime.datetime(2016, 3, 21, 0, 0), 1),
#    (datetime.datetime(2016, 3, 22, 0, 0), 1),
#    (datetime.datetime(2016, 3, 23, 0, 0), 1),
#    (datetime.datetime(2016, 3, 24, 0, 0), 1),
#    (datetime.datetime(2016, 3, 25, 0, 0), 1),
#    (datetime.datetime(2016, 3, 26, 0, 0), 1),
#    (datetime.datetime(2016, 3, 27, 0, 0), 1),
#    (datetime.datetime(2016, 3, 28, 0, 0), 1),
#    (datetime.datetime(2016, 3, 29, 0, 0), 1),
#    (datetime.datetime(2016, 3, 30, 0, 0), 1),
#    (datetime.datetime(2016, 3, 31, 0, 0), 1),
#    (datetime.datetime(2016, 4, 1, 0, 0), 1),
#    (datetime.datetime(2016, 4, 2, 0, 0), 1),
#    (datetime.datetime(2016, 4, 3, 0, 0), 1),
#    (datetime.datetime(2016, 4, 4, 0, 0), 1),
#    (datetime.datetime(2016, 4, 5, 0, 0), 1),
#    (datetime.datetime(2016, 4, 6, 0, 0), 1),
#    (datetime.datetime(2016, 4, 7, 0, 0), 1),
#    (datetime.datetime(2016, 4, 8, 0, 0), 1),
#    (datetime.datetime(2016, 4, 9, 0, 0), 1),
#    (datetime.datetime(2016, 4, 10, 0, 0), 1),
#    (datetime.datetime(2016, 4, 11, 0, 0), 1),
#    (datetime.datetime(2016, 4, 12, 0, 0), 1),
#    (datetime.datetime(2016, 4, 13, 0, 0), 1),
#    (datetime.datetime(2016, 4, 14, 0, 0), 1),
#    (datetime.datetime(2016, 4, 15, 0, 0), 1),
#    (datetime.datetime(2016, 4, 16, 0, 0), 1),
#    (datetime.datetime(2016, 4, 17, 0, 0), 1),
#    (datetime.datetime(2016, 4, 18, 0, 0), 1),
#    (datetime.datetime(2016, 4, 19, 0, 0), 1),
#    (datetime.datetime(2016, 4, 20, 0, 0), 1),
#    (datetime.datetime(2016, 4, 21, 0, 0), 1),
#    (datetime.datetime(2016, 4, 22, 0, 0), 1),
#    (datetime.datetime(2016, 4, 23, 0, 0), 1),
#    (datetime.datetime(2016, 4, 24, 0, 0), 1),
#    (datetime.datetime(2016, 4, 25, 0, 0), 1),
#    (datetime.datetime(2016, 4, 26, 0, 0), 1),
#    (datetime.datetime(2016, 4, 27, 0, 0), 1),
#    (datetime.datetime(2016, 4, 28, 0, 0), 1),
#    (datetime.datetime(2016, 4, 29, 0, 0), 1),
#    (datetime.datetime(2016, 4, 30, 0, 0), 1),
#    (datetime.datetime(2016, 5, 1, 0, 0), 1),
#    (datetime.datetime(2016, 5, 2, 0, 0), 1),
#    (datetime.datetime(2016, 5, 3, 0, 0), 1),
#    (datetime.datetime(2016, 5, 4, 0, 0), 1),
#    (datetime.datetime(2016, 5, 5, 0, 0), 1),
#    (datetime.datetime(2016, 5, 6, 0, 0), 1),
#    (datetime.datetime(2016, 5, 7, 0, 0), 1),
#    (datetime.datetime(2016, 5, 8, 0, 0), 1),
#    (datetime.datetime(2016, 5, 9, 0, 0), 1),
#    (datetime.datetime(2016, 5, 10, 0, 0), 1),
#    (datetime.datetime(2016, 5, 11, 0, 0), 1),
#    (datetime.datetime(2016, 5, 12, 0, 0), 1),
#    (datetime.datetime(2016, 5, 13, 0, 0), 1),
#    (datetime.datetime(2016, 5, 14, 0, 0), 1),
#    (datetime.datetime(2016, 5, 15, 0, 0), 1),
#    (datetime.datetime(2016, 5, 16, 0, 0), 1),
#    (datetime.datetime(2016, 5, 17, 0, 0), 1),
#    (datetime.datetime(2016, 5, 18, 0, 0), 1),
#    (datetime.datetime(2016, 5, 19, 0, 0), 1),
#    (datetime.datetime(2016, 5, 20, 0, 0), 1),
#    (datetime.datetime(2016, 5, 21, 0, 0), 1),
#    ...]),
#  (('QUEENS', 'OAK AVENUE'),
#   [('QUEENS', 'OAK AVENUE'),
#    (datetime.datetime(2016, 8, 18, 0, 0), 1),
#    (datetime.datetime(2016, 8, 19, 0, 0), 1),
#    (datetime.datetime(2016, 8, 20, 0, 0), 1),
#    (datetime.datetime(2016, 8, 21, 0, 0), 1),
#    (datetime.datetime(2016, 8, 22, 0, 0), 1),
#    (datetime.datetime(2016, 8, 23, 0, 0), 1),
#    (datetime.datetime(2016, 8, 24, 0, 0), 1),
#    (datetime.datetime(2016, 8, 25, 0, 0), 1),
#    (datetime.datetime(2016, 8, 26, 0, 0), 1),
#    (datetime.datetime(2016, 8, 27, 0, 0), 1),
#    (datetime.datetime(2016, 8, 28, 0, 0), 1),
#    (datetime.datetime(2016, 8, 29, 0, 0), 1),
#    (datetime.datetime(2016, 8, 30, 0, 0), 1),
#    (datetime.datetime(2016, 8, 31, 0, 0), 1),
#    (datetime.datetime(2016, 9, 1, 0, 0), 1),
#    (datetime.datetime(2016, 9, 2, 0, 0), 1),
#    (datetime.datetime(2016, 9, 3, 0, 0), 1),
#    (datetime.datetime(2016, 9, 4, 0, 0), 1),
#    (datetime.datetime(2016, 9, 5, 0, 0), 1),
#    (datetime.datetime(2016, 9, 6, 0, 0), 1),
#    (datetime.datetime(2016, 9, 7, 0, 0), 1),
#    (datetime.datetime(2016, 9, 8, 0, 0), 1),
#    (datetime.datetime(2016, 9, 9, 0, 0), 1),
#    (datetime.datetime(2016, 9, 10, 0, 0), 1),
#    (datetime.datetime(2016, 9, 11, 0, 0), 1),
#    (datetime.datetime(2016, 9, 12, 0, 0), 1),
#    (datetime.datetime(2016, 9, 13, 0, 0), 1),
#    (datetime.datetime(2016, 9, 14, 0, 0), 1),
#    (datetime.datetime(2016, 9, 15, 0, 0), 1),
#    (datetime.datetime(2016, 9, 16, 0, 0), 1),
#    (datetime.datetime(2016, 9, 17, 0, 0), 1),
#    (datetime.datetime(2016, 9, 18, 0, 0), 1),
#    (datetime.datetime(2016, 9, 19, 0, 0), 1),
#    (datetime.datetime(2016, 9, 20, 0, 0), 1),
#    (datetime.datetime(2016, 9, 21, 0, 0), 1),
#    (datetime.datetime(2016, 9, 22, 0, 0), 1),
#    (datetime.datetime(2016, 9, 23, 0, 0), 1),
#    (datetime.datetime(2016, 9, 24, 0, 0), 1),
#    (datetime.datetime(2016, 9, 25, 0, 0), 1),
#    (datetime.datetime(2016, 9, 26, 0, 0), 1),
#    (datetime.datetime(2016, 9, 27, 0, 0), 1),
#    (datetime.datetime(2016, 9, 28, 0, 0), 1),
#    (datetime.datetime(2016, 9, 29, 0, 0), 1),
#    (datetime.datetime(2016, 9, 30, 0, 0), 1),
#    (datetime.datetime(2016, 10, 1, 0, 0), 1),
# ...
#    (datetime.datetime(2019, 2, 9, 0, 0), 1),
#    (datetime.datetime(2019, 2, 10, 0, 0), 1),
#    (datetime.datetime(2019, 2, 11, 0, 0), 1),
#    (datetime.datetime(2019, 2, 12, 0, 0), 1),
#    (datetime.datetime(2019, 2, 13, 0, 0), 1),
#    (datetime.datetime(2019, 2, 14, 0, 0), 1),
#    (datetime.datetime(2019, 2, 15, 0, 0), 1),
#    (datetime.datetime(2019, 2, 16, 0, 0), 1),
#    (datetime.datetime(2019, 2, 17, 0, 0), 1),
#    (datetime.datetime(2019, 2, 18, 0, 0), 1),
#    (datetime.datetime(2019, 2, 19, 0, 0), 1),
#    (datetime.datetime(2019, 2, 20, 0, 0), 1),
#    (datetime.datetime(2019, 2, 21, 0, 0), 1),
#    (datetime.datetime(2019, 2, 22, 0, 0), 1),
#    (datetime.datetime(2019, 2, 23, 0, 0), 1),
#    (datetime.datetime(2019, 2, 24, 0, 0), 1),
#    (datetime.datetime(2019, 2, 25, 0, 0), 1),
#    (datetime.datetime(2019, 2, 26, 0, 0), 1),
#    (datetime.datetime(2019, 2, 27, 0, 0), 1),
#    (datetime.datetime(2019, 2, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 1, 0, 0), 1),
#    (datetime.datetime(2019, 3, 2, 0, 0), 1),
#    (datetime.datetime(2019, 3, 3, 0, 0), 1),
#    (datetime.datetime(2019, 3, 4, 0, 0), 1),
#    (datetime.datetime(2019, 3, 5, 0, 0), 1),
#    (datetime.datetime(2019, 3, 6, 0, 0), 1),
#    (datetime.datetime(2019, 3, 7, 0, 0), 1),
#    (datetime.datetime(2019, 3, 8, 0, 0), 1),
#    (datetime.datetime(2019, 3, 9, 0, 0), 1),
#    (datetime.datetime(2019, 3, 10, 0, 0), 1),
#    (datetime.datetime(2019, 3, 11, 0, 0), 1),
#    (datetime.datetime(2019, 3, 12, 0, 0), 1),
#    (datetime.datetime(2019, 3, 13, 0, 0), 1),
#    (datetime.datetime(2019, 3, 14, 0, 0), 1),
#    (datetime.datetime(2019, 3, 15, 0, 0), 1),
#    (datetime.datetime(2019, 3, 16, 0, 0), 1),
#    (datetime.datetime(2019, 3, 17, 0, 0), 1),
#    (datetime.datetime(2019, 3, 18, 0, 0), 1),
#    (datetime.datetime(2019, 3, 19, 0, 0), 1),
#    (datetime.datetime(2019, 3, 20, 0, 0), 1),
#    (datetime.datetime(2019, 3, 21, 0, 0), 1),
#    (datetime.datetime(2019, 3, 22, 0, 0), 1),
#    (datetime.datetime(2019, 3, 23, 0, 0), 1),
#    (datetime.datetime(2019, 3, 24, 0, 0), 1),
#    (datetime.datetime(2019, 3, 25, 0, 0), 1),
#    (datetime.datetime(2019, 3, 26, 0, 0), 1),
#    (datetime.datetime(2019, 3, 27, 0, 0), 1),
#    (datetime.datetime(2019, 3, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 29, 0, 0), 1),
#    (datetime.datetime(2019, 3, 30, 0, 0), 1),
#    (datetime.datetime(2019, 3, 31, 0, 0), 1),
#    (datetime.datetime(2019, 4, 1, 0, 0), 1),
#    (datetime.datetime(2019, 4, 2, 0, 0), 1),
#    (datetime.datetime(2019, 4, 3, 0, 0), 1),
#    (datetime.datetime(2019, 4, 4, 0, 0), 1),
#    (datetime.datetime(2019, 4, 5, 0, 0), 1),
#    (datetime.datetime(2019, 4, 6, 0, 0), 1),
#    (datetime.datetime(2019, 4, 7, 0, 0), 1),
#    (datetime.datetime(2019, 4, 8, 0, 0), 1),
#    (datetime.datetime(2019, 4, 9, 0, 0), 1),
#    (datetime.datetime(2019, 4, 10, 0, 0), 1),
#    (datetime.datetime(2019, 4, 11, 0, 0), 1),
#    (datetime.datetime(2019, 4, 12, 0, 0), 1),
#    (datetime.datetime(2019, 4, 13, 0, 0), 1),
#    (datetime.datetime(2019, 4, 14, 0, 0), 1),
#    (datetime.datetime(2019, 4, 15, 0, 0), 1),
#    (datetime.datetime(2019, 4, 16, 0, 0), 1),
#    (datetime.datetime(2019, 4, 17, 0, 0), 1),
#    (datetime.datetime(2019, 4, 18, 0, 0), 1),
#    (datetime.datetime(2019, 4, 19, 0, 0), 1),
#    (datetime.datetime(2019, 4, 20, 0, 0), 1),
#    (datetime.datetime(2019, 4, 21, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2019, 1, 23, 0, 0), 1),
#    (datetime.datetime(2019, 1, 24, 0, 0), 1),
#    (datetime.datetime(2019, 1, 25, 0, 0), 1),
#    (datetime.datetime(2019, 1, 26, 0, 0), 1),
#    (datetime.datetime(2019, 1, 27, 0, 0), 1),
#    (datetime.datetime(2019, 1, 28, 0, 0), 1),
#    (datetime.datetime(2019, 1, 29, 0, 0), 1),
#    (datetime.datetime(2019, 1, 30, 0, 0), 1),
#    (datetime.datetime(2019, 1, 31, 0, 0), 1),
#    (datetime.datetime(2019, 2, 1, 0, 0), 1),
#    (datetime.datetime(2019, 2, 2, 0, 0), 1),
#    (datetime.datetime(2019, 2, 3, 0, 0), 1),
#    (datetime.datetime(2019, 2, 4, 0, 0), 1),
#    (datetime.datetime(2019, 2, 5, 0, 0), 1),
#    (datetime.datetime(2019, 2, 6, 0, 0), 1),
#    (datetime.datetime(2019, 2, 7, 0, 0), 1),
#    (datetime.datetime(2019, 2, 8, 0, 0), 1),
#    (datetime.datetime(2019, 2, 9, 0, 0), 1),
#    (datetime.datetime(2019, 2, 10, 0, 0), 1),
#    (datetime.datetime(2019, 2, 11, 0, 0), 1),
#    (datetime.datetime(2019, 2, 12, 0, 0), 1),
#    (datetime.datetime(2019, 2, 13, 0, 0), 1),
#    (datetime.datetime(2019, 2, 14, 0, 0), 1),
#    (datetime.datetime(2019, 2, 15, 0, 0), 1),
#    (datetime.datetime(2019, 2, 16, 0, 0), 1),
#    (datetime.datetime(2019, 2, 17, 0, 0), 1),
#    (datetime.datetime(2019, 2, 18, 0, 0), 1),
#    (datetime.datetime(2019, 2, 19, 0, 0), 1),
#    (datetime.datetime(2019, 2, 20, 0, 0), 1),
#    (datetime.datetime(2019, 2, 21, 0, 0), 1),
#    (datetime.datetime(2019, 2, 22, 0, 0), 1),
#    (datetime.datetime(2019, 2, 23, 0, 0), 1),
#    (datetime.datetime(2019, 2, 24, 0, 0), 1),
#    (datetime.datetime(2019, 2, 25, 0, 0), 1),
#    (datetime.datetime(2019, 2, 26, 0, 0), 1),
#    (datetime.datetime(2019, 2, 27, 0, 0), 1),
#    (datetime.datetime(2019, 2, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 1, 0, 0), 1),
#    (datetime.datetime(2019, 3, 2, 0, 0), 1),
#    (datetime.datetime(2019, 3, 3, 0, 0), 1),
#    (datetime.datetime(2019, 3, 4, 0, 0), 1),
#    (datetime.datetime(2019, 3, 5, 0, 0), 1),
#    (datetime.datetime(2019, 3, 6, 0, 0), 1),
#    (datetime.datetime(2019, 3, 7, 0, 0), 1),
#    (datetime.datetime(2019, 3, 8, 0, 0), 1),
#    (datetime.datetime(2019, 3, 9, 0, 0), 1),
#    (datetime.datetime(2019, 3, 10, 0, 0), 1),
#    (datetime.datetime(2019, 3, 11, 0, 0), 1),
#    (datetime.datetime(2019, 3, 12, 0, 0), 1),
#    (datetime.datetime(2019, 3, 13, 0, 0), 1),
#    (datetime.datetime(2019, 3, 14, 0, 0), 1),
#    (datetime.datetime(2019, 3, 15, 0, 0), 1),
#    (datetime.datetime(2019, 3, 16, 0, 0), 1),
#    (datetime.datetime(2019, 3, 17, 0, 0), 1),
#    (datetime.datetime(2019, 3, 18, 0, 0), 1),
#    (datetime.datetime(2019, 3, 19, 0, 0), 1),
#    (datetime.datetime(2019, 3, 20, 0, 0), 1),
#    (datetime.datetime(2019, 3, 21, 0, 0), 1),
#    (datetime.datetime(2019, 3, 22, 0, 0), 1),
#    (datetime.datetime(2019, 3, 23, 0, 0), 1),
#    (datetime.datetime(2019, 3, 24, 0, 0), 1),
#    (datetime.datetime(2019, 3, 25, 0, 0), 1),
#    (datetime.datetime(2019, 3, 26, 0, 0), 1),
#    (datetime.datetime(2019, 3, 27, 0, 0), 1),
#    (datetime.datetime(2019, 3, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 29, 0, 0), 1),
#    (datetime.datetime(2019, 3, 30, 0, 0), 1),
#    (datetime.datetime(2019, 3, 31, 0, 0), 1),
#    (datetime.datetime(2019, 4, 1, 0, 0), 1),
#    (datetime.datetime(2019, 4, 2, 0, 0), 1),
#    (datetime.datetime(2019, 4, 3, 0, 0), 1),
#    (datetime.datetime(2019, 4, 4, 0, 0), 1),
#    (datetime.datetime(2019, 4, 5, 0, 0), 1),
#    (datetime.datetime(2019, 4, 6, 0, 0), 1),
#    (datetime.datetime(2019, 4, 7, 0, 0), 1),
#    (datetime.datetime(2019, 4, 8, 0, 0), 1),
#    (datetime.datetime(2019, 4, 9, 0, 0), 1),
#    (datetime.datetime(2019, 4, 10, 0, 0), 1),
#    (datetime.datetime(2019, 4, 11, 0, 0), 1),
#    (datetime.datetime(2019, 4, 12, 0, 0), 1),
#    (datetime.datetime(2019, 4, 13, 0, 0), 1),
#    (datetime.datetime(2019, 4, 14, 0, 0), 1),
#    (datetime.datetime(2019, 4, 15, 0, 0), 1),
#    (datetime.datetime(2019, 4, 16, 0, 0), 1),
#    (datetime.datetime(2019, 4, 17, 0, 0), 1),
#    (datetime.datetime(2019, 4, 18, 0, 0), 1),
#    (datetime.datetime(2019, 4, 19, 0, 0), 1),
#    (datetime.datetime(2019, 4, 20, 0, 0), 1),
#    (datetime.datetime(2019, 4, 21, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2019, 1, 23, 0, 0), 1),
#    (datetime.datetime(2019, 1, 24, 0, 0), 1),
#    (datetime.datetime(2019, 1, 25, 0, 0), 1),
#    (datetime.datetime(2019, 1, 26, 0, 0), 1),
#    (datetime.datetime(2019, 1, 27, 0, 0), 1),
#    (datetime.datetime(2019, 1, 28, 0, 0), 1),
#    (datetime.datetime(2019, 1, 29, 0, 0), 1),
#    (datetime.datetime(2019, 1, 30, 0, 0), 1),
#    (datetime.datetime(2019, 1, 31, 0, 0), 1),
#    (datetime.datetime(2019, 2, 1, 0, 0), 1),
#    (datetime.datetime(2019, 2, 2, 0, 0), 1),
#    (datetime.datetime(2019, 2, 3, 0, 0), 1),
#    (datetime.datetime(2019, 2, 4, 0, 0), 1),
#    (datetime.datetime(2019, 2, 5, 0, 0), 1),
#    (datetime.datetime(2019, 2, 6, 0, 0), 1),
#    (datetime.datetime(2019, 2, 7, 0, 0), 1),
#    (datetime.datetime(2019, 2, 8, 0, 0), 1),
#    (datetime.datetime(2019, 2, 9, 0, 0), 1),
#    (datetime.datetime(2019, 2, 10, 0, 0), 1),
#    (datetime.datetime(2019, 2, 11, 0, 0), 1),
#    (datetime.datetime(2019, 2, 12, 0, 0), 1),
#    (datetime.datetime(2019, 2, 13, 0, 0), 1),
#    (datetime.datetime(2019, 2, 14, 0, 0), 1),
#    (datetime.datetime(2019, 2, 15, 0, 0), 1),
#    (datetime.datetime(2019, 2, 16, 0, 0), 1),
#    (datetime.datetime(2019, 2, 17, 0, 0), 1),
#    (datetime.datetime(2019, 2, 18, 0, 0), 1),
#    (datetime.datetime(2019, 2, 19, 0, 0), 1),
#    (datetime.datetime(2019, 2, 20, 0, 0), 1),
#    (datetime.datetime(2019, 2, 21, 0, 0), 1),
#    (datetime.datetime(2019, 2, 22, 0, 0), 1),
#    (datetime.datetime(2019, 2, 23, 0, 0), 1),
#    (datetime.datetime(2019, 2, 24, 0, 0), 1),
#    (datetime.datetime(2019, 2, 25, 0, 0), 1),
#    (datetime.datetime(2019, 2, 26, 0, 0), 1),
#    (datetime.datetime(2019, 2, 27, 0, 0), 1),
#    (datetime.datetime(2019, 2, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 1, 0, 0), 1),
#    (datetime.datetime(2019, 3, 2, 0, 0), 1),
#    (datetime.datetime(2019, 3, 3, 0, 0), 1),
#    (datetime.datetime(2019, 3, 4, 0, 0), 1),
#    (datetime.datetime(2019, 3, 5, 0, 0), 1),
#    (datetime.datetime(2019, 3, 6, 0, 0), 1),
#    (datetime.datetime(2019, 3, 7, 0, 0), 1),
#    (datetime.datetime(2019, 3, 8, 0, 0), 1),
#    (datetime.datetime(2019, 3, 9, 0, 0), 1),
#    (datetime.datetime(2019, 3, 10, 0, 0), 1),
#    (datetime.datetime(2019, 3, 11, 0, 0), 1),
#    (datetime.datetime(2019, 3, 12, 0, 0), 1),
#    (datetime.datetime(2019, 3, 13, 0, 0), 1),
#    (datetime.datetime(2019, 3, 14, 0, 0), 1),
#    (datetime.datetime(2019, 3, 15, 0, 0), 1),
#    (datetime.datetime(2019, 3, 16, 0, 0), 1),
#    (datetime.datetime(2019, 3, 17, 0, 0), 1),
#    (datetime.datetime(2019, 3, 18, 0, 0), 1),
#    (datetime.datetime(2019, 3, 19, 0, 0), 1),
#    (datetime.datetime(2019, 3, 20, 0, 0), 1),
#    (datetime.datetime(2019, 3, 21, 0, 0), 1),
#    (datetime.datetime(2019, 3, 22, 0, 0), 1),
#    (datetime.datetime(2019, 3, 23, 0, 0), 1),
#    (datetime.datetime(2019, 3, 24, 0, 0), 1),
#    (datetime.datetime(2019, 3, 25, 0, 0), 1),
#    (datetime.datetime(2019, 3, 26, 0, 0), 1),
#    (datetime.datetime(2019, 3, 27, 0, 0), 1),
#    (datetime.datetime(2019, 3, 28, 0, 0), 1),
#    (datetime.datetime(2019, 3, 29, 0, 0), 1),
#    (datetime.datetime(2019, 3, 30, 0, 0), 1),
#    (datetime.datetime(2019, 3, 31, 0, 0), 1),
#    (datetime.datetime(2019, 4, 1, 0, 0), 1),
#    (datetime.datetime(2019, 4, 2, 0, 0), 1),
#    (datetime.datetime(2019, 4, 3, 0, 0), 1),
#    (datetime.datetime(2019, 4, 4, 0, 0), 1),
#    (datetime.datetime(2019, 4, 5, 0, 0), 1),
#    (datetime.datetime(2019, 4, 6, 0, 0), 1),
#    (datetime.datetime(2019, 4, 7, 0, 0), 1),
#    (datetime.datetime(2019, 4, 8, 0, 0), 1),
#    (datetime.datetime(2019, 4, 9, 0, 0), 1),
#    (datetime.datetime(2019, 4, 10, 0, 0), 1),
#    (datetime.datetime(2019, 4, 11, 0, 0), 1),
#    (datetime.datetime(2019, 4, 12, 0, 0), 1),
#    (datetime.datetime(2019, 4, 13, 0, 0), 1),
#    (datetime.datetime(2019, 4, 14, 0, 0), 1),
#    (datetime.datetime(2019, 4, 15, 0, 0), 1),
#    (datetime.datetime(2019, 4, 16, 0, 0), 1),
#    (datetime.datetime(2019, 4, 17, 0, 0), 1),
#    (datetime.datetime(2019, 4, 18, 0, 0), 1),
#    (datetime.datetime(2019, 4, 19, 0, 0), 1),
#    (datetime.datetime(2019, 4, 20, 0, 0), 1),
#    (datetime.datetime(2019, 4, 21, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2016, 12, 16, 0, 0), 1),
#    (datetime.datetime(2016, 12, 17, 0, 0), 1),
#    (datetime.datetime(2016, 12, 18, 0, 0), 1),
#    (datetime.datetime(2016, 12, 19, 0, 0), 1),
#    (datetime.datetime(2016, 12, 20, 0, 0), 1),
#    (datetime.datetime(2016, 12, 21, 0, 0), 1),
#    (datetime.datetime(2016, 12, 22, 0, 0), 1),
#    (datetime.datetime(2016, 12, 23, 0, 0), 1),
#    (datetime.datetime(2016, 12, 24, 0, 0), 1),
#    (datetime.datetime(2016, 12, 25, 0, 0), 1),
#    (datetime.datetime(2016, 12, 26, 0, 0), 1),
#    (datetime.datetime(2016, 12, 27, 0, 0), 1),
#    (datetime.datetime(2016, 12, 28, 0, 0), 1),
#    (datetime.datetime(2016, 12, 29, 0, 0), 1),
#    (datetime.datetime(2016, 12, 30, 0, 0), 1),
#    (datetime.datetime(2016, 12, 31, 0, 0), 1),
#    (datetime.datetime(2017, 1, 1, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2017, 7, 23, 0, 0), 1),
#    (datetime.datetime(2017, 7, 24, 0, 0), 1),
#    (datetime.datetime(2017, 7, 25, 0, 0), 1),
#    (datetime.datetime(2017, 7, 26, 0, 0), 1),
#    (datetime.datetime(2017, 7, 27, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2018, 6, 7, 0, 0), 1),
#    (datetime.datetime(2018, 6, 8, 0, 0), 1),
#    (datetime.datetime(2018, 6, 9, 0, 0), 1),
#    (datetime.datetime(2018, 6, 10, 0, 0), 1),
#    (datetime.datetime(2018, 6, 11, 0, 0), 1),
#    (datetime.datetime(2018, 6, 12, 0, 0), 1),
#    (datetime.datetime(2018, 6, 13, 0, 0), 1),
#    (datetime.datetime(2018, 6, 14, 0, 0), 1),
#    (datetime.datetime(2018, 6, 15, 0, 0), 1),
#    (datetime.datetime(2018, 6, 16, 0, 0), 1),
#    (datetime.datetime(2018, 6, 17, 0, 0), 1),
#    (datetime.datetime(2018, 6, 18, 0, 0), 1),
#    (datetime.datetime(2018, 6, 19, 0, 0), 1),
#    (datetime.datetime(2018, 6, 20, 0, 0), 1),
#    (datetime.datetime(2018, 6, 21, 0, 0), 1),
#    (datetime.datetime(2018, 6, 22, 0, 0), 1),
#    (datetime.datetime(2018, 6, 23, 0, 0), 1),
#    (datetime.datetime(2018, 6, 24, 0, 0), 1),
#    (datetime.datetime(2018, 6, 25, 0, 0), 1),
#    (datetime.datetime(2018, 6, 26, 0, 0), 1),
#    (datetime.datetime(2018, 6, 27, 0, 0), 1),
#    (datetime.datetime(2018, 6, 28, 0, 0), 1),
#    (datetime.datetime(2018, 6, 29, 0, 0), 1),
#    (datetime.datetime(2018, 6, 30, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2018, 6, 7, 0, 0), 1),
#    (datetime.datetime(2018, 6, 8, 0, 0), 1),
#    (datetime.datetime(2018, 6, 9, 0, 0), 1),
#    (datetime.datetime(2018, 6, 10, 0, 0), 1),
#    (datetime.datetime(2018, 6, 11, 0, 0), 1),
#    (datetime.datetime(2018, 6, 12, 0, 0), 1),
#    (datetime.datetime(2018, 6, 13, 0, 0), 1),
#    (datetime.datetime(2018, 6, 14, 0, 0), 1),
#    (datetime.datetime(2018, 6, 15, 0, 0), 1),
#    (datetime.datetime(2018, 6, 16, 0, 0), 1),
#    (datetime.datetime(2018, 6, 17, 0, 0), 1),
#    (datetime.datetime(2018, 6, 18, 0, 0), 1),
#    (datetime.datetime(2018, 6, 19, 0, 0), 1),
#    (datetime.datetime(2018, 6, 20, 0, 0), 1),
#    (datetime.datetime(2018, 6, 21, 0, 0), 1),
#    (datetime.datetime(2018, 6, 22, 0, 0), 1),
#    (datetime.datetime(2018, 6, 23, 0, 0), 1),
#    (datetime.datetime(2018, 6, 24, 0, 0), 1),
#    (datetime.datetime(2018, 6, 25, 0, 0), 1),
#    (datetime.datetime(2018, 6, 26, 0, 0), 1),
#    (datetime.datetime(2018, 6, 27, 0, 0), 1),
#    (datetime.datetime(2018, 6, 28, 0, 0), 1),
#    (datetime.datetime(2018, 6, 29, 0, 0), 1),
#    (datetime.datetime(2018, 6, 30, 0, 0), 1),
#    ('BRONX', 'VALLES AVENUE'),
#    (datetime.datetime(2018, 6, 7, 0, 0), 1),
#    (datetime.datetime(2018, 6, 8, 0, 0), 1),
#    (datetime.datetime(2018, 6, 9, 0, 0), 1),
#    (datetime.datetime(2018, 6, 10, 0, 0), 1),
#    (datetime.datetime(2018, 6, 11, 0, 0), 1),
#    (datetime.datetime(2018, 6, 12, 0, 0), 1),
#    (datetime.datetime(2018, 6, 13, 0, 0), 1),
#    (datetime.datetime(2018, 6, 14, 0, 0), 1),
#    (datetime.datetime(2018, 6, 15, 0, 0), 1),
#    (datetime.datetime(2018, 6, 16, 0, 0), 1),
#    (datetime.datetime(2018, 6, 17, 0, 0), 1),
#    (datetime.datetime(2018, 6, 18, 0, 0), 1),
#    (datetime.datetime(2018, 6, 19, 0, 0), 1),
#    (datetime.datetime(2018, 6, 20, 0, 0), 1),
#    (datetime.datetime(2018, 6, 21, 0, 0), 1),
#    (datetime.datetime(2018, 6, 22, 0, 0), 1),
#    (datetime.datetime(2018, 6, 23, 0, 0), 1),
#    (datetime.datetime(2018, 6, 24, 0, 0), 1),
#    (datetime.datetime(2018, 6, 25, 0, 0), 1),
#    (datetime.datetime(2018, 6, 26, 0, 0), 1),
#    (datetime.datetime(2018, 6, 27, 0, 0), 1),
#    (datetime.datetime(2018, 6, 28, 0, 0), 1),
#    (datetime.datetime(2018, 6, 29, 0, 0), 1),
#    (datetime.datetime(2018, 6, 30, 0, 0), 1),
#    ...])]

# %%
# permit_df.columns.to_list()

# %%
# permit_df['EmergencyIssueDate']

# %%
# permit_df['CreatedOn'].str[0:10]

# %%
# permit_df['CreatedOn'] = pd.to_datetime(permit_df['CreatedOn'].str[:10])

# %%
# permit_df['CreatedOn'].sort_values(ascending=True)

# %%
# permit_df['dow'] = pd.to_datetime(permit_df['CreatedOn']).dt.dayofweek
# permit_df['day'] = pd.to_datetime(permit_df['CreatedOn']).dt.day
# permit_df['year'] = pd.to_datetime(permit_df['CreatedOn']).dt.year

# %%
# permit_year = permit_df[['year','PermitNumber']].groupby('year').count().reset_index()
# permit_year.head()

# %%
# plt.figure(figsize=(10,5))
# plt.bar(crash_year.year,crash_year.Injured,color='lightblue')
# plt.title('Number of Injuries from 2012 to 2020',fontsize=20,color='white')
# plt.ylabel('Injuries',fontsize=15,color='white')
# plt.xticks(crash_year.year,fontsize=13,color='white')
# plt.yticks(fontsize=13,color='white')
# plt.grid(linestyle='--',axis='y')
# plt.savefig('injuries',dpi=300)
# plt.show()

# %%
# missing_value_permit = permit_df.isna().sum().to_frame(name='NaN_number')
# missing_value_permit.sort_values('NaN_number',inplace=True,ascending=False)

# %%
# missing_value_permit.plot.bar(color='blue',figsize=(15,7))
# plt.title('Missing Value of Street Construction Permit dataset',fontsize=15)
# plt.legend()
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# #import geopandas as gpd
# import dask.dataframe as dd
# from dask.diagnostics import ProgressBar
# from datetime import datetime
# from matplotlib import pyplot as plt
# import warnings
# %matplotlib inline
# warnings.filterwarnings('ignore')

# permit_dd = dd.read_csv('./data/Street_Construction_Permits.csv',dtype=str)
# permit_dd['CreatedOn'] = dd.to_datetime(permit_dd['CreatedOn'].str[:10])

# permit_dd['dow'] = dd.to_datetime(permit_dd['CreatedOn']).dt.dayofweek
# permit_dd['day'] = dd.to_datetime(permit_dd['CreatedOn']).dt.day
# permit_dd['year'] = dd.to_datetime(permit_dd['CreatedOn']).dt.year

# permit_year = permit_dd[['year','PermitNumber']].groupby('year').count().reset_index().compute()
# permit_year['year']= permit_year[permit_year['year'] != '2021']
# permit_year = permit_year[0:-1]
# permit_year.year=permit_year['year'].astype(str)
# permit_year.year = permit_year.year.str[:4]
# permit_year = permit_year[1:].sort_values('year')

# permit = permit_dd.compute()

# %%
# plt.figure(figsize=(10,5))
# plt.bar(permit_year.year,permit_year['PermitNumber'],color='lightblue')
# plt.title('Number of Construction Permits from 2014 to 2020',fontsize=20,color='white')
# plt.ylabel('Number of Permits',fontsize=15,color='white')
# plt.xticks(permit_year.year,fontsize=13,color='white')
# plt.yticks(fontsize=13,color='white')
# plt.grid(linestyle='--',axis='y')
# plt.savefig('permits',dpi=300)
# plt.show()

# %%
# permit_year['PermitNumber'].sum()/len(permit_year['PermitNumber'])
# Out:
# 628370.0
